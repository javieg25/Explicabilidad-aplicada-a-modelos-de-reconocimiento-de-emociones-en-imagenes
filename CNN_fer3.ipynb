# %% [markdown]
# ## 1) Importación de librerías necesarias

# %%
import pandas as pd
import os
import numpy as np
from PIL import Image
import pickle
import time
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation, Conv2D, Dense, Dropout
from tensorflow.keras.layers import Flatten, Input, Reshape, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## 2) Funciones que se van a usar

# %%
"""
Given the main directory of the location of the images, the URL of each image is loaded to a dataframe with his clasification
"""
def loadData(path_main_directory):
    paths_list = list()
    label_list = list()

    for subdirectory in os.listdir(path_main_directory):
        #Build the path of every subdirectory of the main_directory
        path_subdirectory = os.path.join(path_main_directory, subdirectory)

        #Iterate over all the images of the subdirectory adding the path to the dictionary
        for image_name in os.listdir(path_subdirectory):
            image_path = os.path.join(path_subdirectory, image_name)
            paths_list.append(image_path)
            label_list.append(subdirectory)

        init_data_dict = {'path' : paths_list, 'label' : label_list}

    return pd.DataFrame(init_data_dict)

# %%
"""
Given the URL of the images as a list, the information of the size of the images is returned as a dataframe
"""
def getImageSizeInfo(images_path_L):
    #list of the size of each image
    images_size_L = list()
    #List of the width of each image
    images_width_L = list()
    #List of the height of each image
    images_height_L = list()
    #List of the ratio of the size of each image
    images_ratio_L = list()

    for path in images_path_L:
        image = Image.open(path)
        #Get the size of an image (given as a tuple) and append it to the list
        images_size_L.append(image.size)
        #Get the size of the image and append it to the list
        images_width_L.append(image.size[0])
        #Get the height of the image and append it to the list
        images_height_L.append(image.size[1])
        #Get the ratio (width/height) of the image and append it to the list
        images_ratio_L.append(round(image.size[0] / image.size[1], 2))

    #Dictionary with all the information
    image_info_D = {'path' : images_path_L, 'size' : images_size_L, 'width' : images_width_L, 'height' : images_height_L,'ratio' : images_ratio_L}
    #Data frame with all the information
    return pd.DataFrame(image_info_D)

# %%
def loadImages(tams_L, images_path_L, images_class_L):
    images_BW_D = dict()

    for i in range(0, len(tams_L)):
        #List of the representation of the images in black and white as a list
        imgs_BW_L = list()
        #List of the class of each image
        class_BW_L = list()

        for j in range(0, len(images_path_L)):
            #Open image and resize it
            img = Image.open(images_path_L[j]).resize(tams_L[i])
            #Image as a list
            arr = np.asarray(img, dtype = np.int_)
            
            imgs_BW_L.append(arr)
            class_BW_L.append(images_class_L[j])

        images_BW_D[i] = (imgs_BW_L, class_BW_L)
    
    return images_BW_D

# %%
"""
Given the name of the class, returns the associated numeric class
"""
def class_to_numeric(class_list):
    l = list()
    for i in range (0, len(class_list)):
        if(class_list[i] == 'angry'):
            l.append(0)
        elif(class_list[i] == 'happy'):
            l.append(1)
        elif(class_list[i] == 'sad'):
            l.append(2)
    return np.array(l)

# %%
def numeric_to_class(type):
    if(type == 0):
        return 'angry'
    elif(type == 1):
        return 'happy'
    else:
        return 'sad'

# %%
def decode(class_list):
    if(class_list[0] == 1):
        return 'angry'
    elif(class_list[1] == 1):
        return 'happy'
    else:
        return 'sad'

# %%
def createModel(input_shape, pool_size, kernel_size, activation_function):
    inputs = Input(shape=(input_shape), dtype=tf.float64)
    x = Conv2D(64, kernel_size, padding='same', activation=activation_function)(inputs)
    x = MaxPooling2D(pool_size=pool_size)(x)
    x = Dropout(.3)(x)
    
    x = Conv2D(32, kernel_size, padding='same', activation=activation_function)(x)
    x = MaxPooling2D(pool_size=pool_size)(x)
    x = Dropout(.3)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation=activation_function)(x)
    x = Dropout(.5)(x)
    logits = Dense(3, name='logits')(x)
    outputs = Activation('softmax', name='softmax')(logits)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                              optimizer='adam',
                              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 2) Carga del conjunto de datos

# %% [markdown]
# Se van a cargar las URL de las imágenes en un dataframe junto a su clasificación.
#
# El directorio principal está divido en 3 subdirectorios titulados: angry, happy y sad. Por lo que todas las URLs (imágenes) de un directorio tendrán esa clasificación.

# %%
#Main directory of the data
path_main_directory = './fer3'

#Load the data
init_data_df = loadData(path_main_directory)

display(init_data_df.head())
display(init_data_df.tail())
# Out:
#                                     path  label
# 0  ./fer3\angry\PrivateTest_10131363.jpg  angry
# 1  ./fer3\angry\PrivateTest_10304478.jpg  angry
# 2   ./fer3\angry\PrivateTest_1054527.jpg  angry
# 3  ./fer3\angry\PrivateTest_10590091.jpg  angry
# 4   ./fer3\angry\PrivateTest_1109992.jpg  angry
#                                    path label
# 20014  ./fer3\sad\Training_99922913.jpg   sad
# 20015  ./fer3\sad\Training_99943858.jpg   sad
# 20016  ./fer3\sad\Training_99950687.jpg   sad
# 20017  ./fer3\sad\Training_99987906.jpg   sad
# 20018  ./fer3\sad\Training_99996831.jpg   sad

# %% [markdown]
# Se calculan el número de ejemplos de cada clase

# %%
init_data_df['label'].value_counts()
# Out:
# label
# happy    8989
# sad      6077
# angry    4953
# Name: count, dtype: int64

# %% [markdown]
# Y se calcula la frecuencia de cada clase

# %%
init_data_df['label'].value_counts() / init_data_df['label'].count() * 100
# Out:
# label
# happy    44.902343
# sad      30.356162
# angry    24.741496
# Name: count, dtype: float64

# %% [markdown]
# Como se puede ver, la cantidad de datos de cada clase es muy similar, lo cual es una ventaja para entrenar el modelo.

# %% [markdown]
# ## 3) Adaptación del formato de las imágenes

# %% [markdown]
# ### Elección del tamaño:
#
#   La elección del tamaño es muy importante, ya que tendrá efecto en el tiempo de entrenamiento del modelo y en la precisión del mismo. Aunque el tamaño de las imágenes del conjunto de datos elegido sea (48x48), se explorarán otros tamaños para evaluar los modelos con distintas características.

# %% [markdown]
# Se saca la información del tamaño de las imágenes y se guarda en un data frame

# %%
image_info_DF = getImageSizeInfo(init_data_df['path'].values)
display(image_info_DF.head())
# Out:
#                                     path      size  width  height  ratio
# 0  ./fer3\angry\PrivateTest_10131363.jpg  (48, 48)     48      48    1.0
# 1  ./fer3\angry\PrivateTest_10304478.jpg  (48, 48)     48      48    1.0
# 2   ./fer3\angry\PrivateTest_1054527.jpg  (48, 48)     48      48    1.0
# 3  ./fer3\angry\PrivateTest_10590091.jpg  (48, 48)     48      48    1.0
# 4   ./fer3\angry\PrivateTest_1109992.jpg  (48, 48)     48      48    1.0

# %% [markdown]
# Se van a probar con distintos tamaños (todos ellos dependiendientes de la anchura y altura original)

# %%
tams_L = list()
tams_L.append((96, 96)) #original size *2
tams_L.append((48, 48)) #original size
tams_L.append((24, 24)) #original size /2
print(tams_L)
# Out:
# [(96, 96), (48, 48), (24, 24)]

# %% [markdown]
# # Pruebas nuevas tamaños

# %% [markdown]
# Se van a generar varios conjuntos de datos: cada uno de ellos contendrá las imágenes en blanco y negro con distintos tamaños.

# %%
load_images  = loadImages(tams_L, init_data_df['path'].values, init_data_df['label'].values)

# %% [markdown]
# Se ve la forma de cada uno de los conjuntos de datos

# %%
for i in range(0, len(tams_L)):
    print(np.array(load_images[i][0]).shape)
    print(np.array(load_images[i][1]).shape)
# Out:
# (20019, 96, 96)
# (20019,)
# (20019, 48, 48)
# (20019,)
# (20019, 24, 24)
# (20019,)

# %% [markdown]
# Se visualiza una imagen de prueba para ver los cambios realizados tras redimensionar

# %%
print("Clase: ", load_images[0][1][1])
for i in range (0, len(tams_L)):
    image = load_images[i][0][1]
    plt.imshow(image)
    plt.show()
# Out:
# Clase:  angry

# %%
#Dictionary with the train test splits for all the representations
load_train_test = dict()
for i in range(0, len(tams_L)):
    X_train, X_test, y_train, y_test = train_test_split(load_images[i][0], load_images[i][1], test_size=0.2,shuffle=True)
    load_train_test[i] = (np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test))
    print('X_train shape:', np.array(X_train).shape, 'y_train shape:', np.array(y_train).shape, 'X_test shape:', np.array(X_test).shape, 'y_test shape:', np.array(y_test).shape)
# Out:
# X_train shape: (16015, 96, 96) y_train shape: (16015,) X_test shape: (4004, 96, 96) y_test shape: (4004,)
# X_train shape: (16015, 48, 48) y_train shape: (16015,) X_test shape: (4004, 48, 48) y_test shape: (4004,)
# X_train shape: (16015, 24, 24) y_train shape: (16015,) X_test shape: (4004, 24, 24) y_test shape: (4004,)

# %%
#create a model for each image size, activation function, kernel size and pooling size
activations_functions = ['relu', 'sigmoid']
kernel_sizes = [2,6]
pooling_sizes = [2,3]

modelsTams = dict()
for i in range(0, len(tams_L)):
    models = dict()
    j=0
    for pool_size in pooling_sizes:
        for kernel_size in kernel_sizes:
            for activation_function in activations_functions:
                #size of the input images
                l = list(tams_L[i]) #original size
                l[0], l[1] = l[1], l[0] #transpose
                l.append(1) #include last channel
                model = createModel(l, pool_size, kernel_size, activation_function);
                models[j] = model
                j += 1
    modelsTams[i] = models
# Out:
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#print the summary of each model
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        modelsTams[i][j].summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 96, 96, 64)        320
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 48, 48, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        8224
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 256)               4718848
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 4728163 (18.04 MB)
# Trainable params: 4728163 (18.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        8224
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten_1 (Flatten)         (None, 18432)             0
#
#  dense_1 (Dense)             (None, 256)               4718848
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 4728163 (18.04 MB)
# Trainable params: 4728163 (18.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 96, 96, 64)        2368
#
#  max_pooling2d_4 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 32)        73760
#
#  max_pooling2d_5 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten_2 (Flatten)         (None, 18432)             0
#
#  dense_2 (Dense)             (None, 256)               4718848
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 4795747 (18.29 MB)
# Trainable params: 4795747 (18.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_6 (Conv2D)           (None, 96, 96, 64)        2368
#
#  max_pooling2d_6 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 32)        73760
#
#  max_pooling2d_7 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 24, 24, 32)        0
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_3 (Dense)             (None, 256)               4718848
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 4795747 (18.29 MB)
# Trainable params: 4795747 (18.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 96, 96, 64)        320
#
#  max_pooling2d_8 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        8224
#
#  max_pooling2d_9 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_4 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 256)               819456
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 828771 (3.16 MB)
# Trainable params: 828771 (3.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 96, 96, 64)        320
#
#  max_pooling2d_10 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_15 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        8224
#
#  max_pooling2d_11 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_5 (Flatten)         (None, 3200)              0
#
#  dense_5 (Dense)             (None, 256)               819456
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 828771 (3.16 MB)
# Trainable params: 828771 (3.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_12 (Conv2D)          (None, 96, 96, 64)        2368
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        73760
#
#  max_pooling2d_13 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_19 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_6 (Flatten)         (None, 3200)              0
#
#  dense_6 (Dense)             (None, 256)               819456
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 896355 (3.42 MB)
# Trainable params: 896355 (3.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_14 (Conv2D)          (None, 96, 96, 64)        2368
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 32)        73760
#
#  max_pooling2d_15 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_22 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_7 (Flatten)         (None, 3200)              0
#
#  dense_7 (Dense)             (None, 256)               819456
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 896355 (3.42 MB)
# Trainable params: 896355 (3.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_16 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_16 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_24 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 32)        8224
#
#  max_pooling2d_17 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_8 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 256)               1179904
#
#  dropout_26 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 1189219 (4.54 MB)
# Trainable params: 1189219 (4.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_18 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_27 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 32)        8224
#
#  max_pooling2d_19 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_28 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_9 (Flatten)         (None, 4608)              0
#
#  dense_9 (Dense)             (None, 256)               1179904
#
#  dropout_29 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 1189219 (4.54 MB)
# Trainable params: 1189219 (4.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_20 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_20 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_30 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 32)        73760
#
#  max_pooling2d_21 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_31 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_10 (Flatten)        (None, 4608)              0
#
#  dense_10 (Dense)            (None, 256)               1179904
#
#  dropout_32 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 1256803 (4.79 MB)
# Trainable params: 1256803 (4.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_22 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_22 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_33 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 24, 24, 32)        73760
#
#  max_pooling2d_23 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_34 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_11 (Flatten)        (None, 4608)              0
#
#  dense_11 (Dense)            (None, 256)               1179904
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 1256803 (4.79 MB)
# Trainable params: 1256803 (4.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_24 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_24 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_36 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 32)        8224
#
#  max_pooling2d_25 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_37 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_12 (Dense)            (None, 256)               205056
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 214371 (837.39 KB)
# Trainable params: 214371 (837.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_26 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_26 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_39 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 32)        8224
#
#  max_pooling2d_27 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_40 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_13 (Flatten)        (None, 800)               0
#
#  dense_13 (Dense)            (None, 256)               205056
#
#  dropout_41 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 214371 (837.39 KB)
# Trainable params: 214371 (837.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_28 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_28 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_42 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 32)        73760
#
#  max_pooling2d_29 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_43 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_14 (Flatten)        (None, 800)               0
#
#  dense_14 (Dense)            (None, 256)               205056
#
#  dropout_44 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 281955 (1.08 MB)
# Trainable params: 281955 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_30 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_30 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_45 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 32)        73760
#
#  max_pooling2d_31 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_46 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_15 (Flatten)        (None, 800)               0
#
#  dense_15 (Dense)            (None, 256)               205056
#
#  dropout_47 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 281955 (1.08 MB)
# Trainable params: 281955 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_32 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_32 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_48 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_33 (Conv2D)          (None, 12, 12, 32)        8224
#
#  max_pooling2d_33 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_49 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_16 (Flatten)        (None, 1152)              0
#
#  dense_16 (Dense)            (None, 256)               295168
#
#  dropout_50 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 304483 (1.16 MB)
# Trainable params: 304483 (1.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_34 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_34 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_51 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 12, 12, 32)        8224
#
#  max_pooling2d_35 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_52 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_17 (Flatten)        (None, 1152)              0
#
#  dense_17 (Dense)            (None, 256)               295168
#
#  dropout_53 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 304483 (1.16 MB)
# Trainable params: 304483 (1.16 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_36 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_36 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_54 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_37 (Conv2D)          (None, 12, 12, 32)        73760
#
#  max_pooling2d_37 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_55 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_18 (Flatten)        (None, 1152)              0
#
#  dense_18 (Dense)            (None, 256)               295168
#
#  dropout_56 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 372067 (1.42 MB)
# Trainable params: 372067 (1.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_38 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_38 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_57 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 12, 12, 32)        73760
#
#  max_pooling2d_39 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_58 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_19 (Flatten)        (None, 1152)              0
#
#  dense_19 (Dense)            (None, 256)               295168
#
#  dropout_59 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 372067 (1.42 MB)
# Trainable params: 372067 (1.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_40 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_60 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 32)          8224
#
#  max_pooling2d_41 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_61 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_20 (Flatten)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 256)               33024
#
#  dropout_62 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 42339 (165.39 KB)
# Trainable params: 42339 (165.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_42 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_42 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_63 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 32)          8224
#
#  max_pooling2d_43 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_64 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_21 (Flatten)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 256)               33024
#
#  dropout_65 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 42339 (165.39 KB)
# Trainable params: 42339 (165.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_44 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_44 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_66 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 32)          73760
#
#  max_pooling2d_45 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_67 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_22 (Flatten)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 256)               33024
#
#  dropout_68 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 109923 (429.39 KB)
# Trainable params: 109923 (429.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_46 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_46 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_69 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 32)          73760
#
#  max_pooling2d_47 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_70 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_23 (Flatten)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 256)               33024
#
#  dropout_71 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 3)                 771
#
#  softmax (Activation)        (None, 3)                 0
#
# =================================================================
# Total params: 109923 (429.39 KB)
# Trainable params: 109923 (429.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#data conditioning for each model
train_test_conditioned = dict()

for i in range(0, len(tams_L)):
    X_train = load_train_test[i][0]
    X_train = X_train.astype('float32') / 255
    
    X_test = load_train_test[i][1]
    X_test = X_test.astype('float32') / 255
    
    y_train = load_train_test[i][2]
    y_train = class_to_numeric(y_train) # Converts the string class to numeric class
    y_train = to_categorical(y_train) # Converts the classes into one-hot-vector
    
    y_test = load_train_test[i][3]
    y_test = class_to_numeric(y_test) # Converts the string class to numeric class
    y_test = to_categorical(y_test) # Converts the classes into one-hot-vector

    print('X_train shape:', X_train.shape, 'X_test shape:', X_test.shape, 'y_train shape:', y_train.shape, 'y_test shape:', y_test.shape)
    
    train_test_conditioned[i] = (X_train, X_test, y_train, y_test)
# Out:
# X_train shape: (16015, 96, 96) X_test shape: (4004, 96, 96) y_train shape: (16015, 3) y_test shape: (4004, 3)
# X_train shape: (16015, 48, 48) X_test shape: (4004, 48, 48) y_train shape: (16015, 3) y_test shape: (4004, 3)
# X_train shape: (16015, 24, 24) X_test shape: (4004, 24, 24) y_train shape: (16015, 3) y_test shape: (4004, 3)

# %% [markdown]
# ## Train the models

# %%
#train the models
times = list()
accuracies = list()
for i in range(0, len(tams_L)):
    time_tam = list()
    accuracy_tam = list()
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        start = time.time()
        history = modelsTams[i][j].fit(train_test_conditioned[i][0],
              train_test_conditioned[i][2],
              epochs=20,
              batch_size=128,
              verbose=1,
              validation_data=(train_test_conditioned[i][1], train_test_conditioned[i][3])
              )
        stop = time.time()
        time_tam.append(stop-start)
        accuracy_tam.append(history.history['accuracy'][19])
    times.append(time_tam)
    accuracies.append(accuracy_tam)
# Out:
# Model  0 0
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 126/126 [==============================] - 28s 215ms/step - loss: 1.1297 - accuracy: 0.4295 - val_loss: 1.0542 - val_accuracy: 0.4503
# Epoch 2/20
# 126/126 [==============================] - 28s 224ms/step - loss: 1.0305 - accuracy: 0.4799 - val_loss: 1.0152 - val_accuracy: 0.4998
# Epoch 3/20
# 126/126 [==============================] - 29s 232ms/step - loss: 0.9931 - accuracy: 0.5107 - val_loss: 0.9717 - val_accuracy: 0.5270
# Epoch 4/20
# 126/126 [==============================] - 30s 238ms/step - loss: 0.9583 - accuracy: 0.5434 - val_loss: 0.9429 - val_accuracy: 0.5425
# Epoch 5/20
# 126/126 [==============================] - 30s 236ms/step - loss: 0.9363 - accuracy: 0.5539 - val_loss: 0.9245 - val_accuracy: 0.5504
# Epoch 6/20
# 126/126 [==============================] - 29s 231ms/step - loss: 0.9149 - accuracy: 0.5657 - val_loss: 0.8934 - val_accuracy: 0.5697
# Epoch 7/20
# 126/126 [==============================] - 30s 240ms/step - loss: 0.8934 - accuracy: 0.5818 - val_loss: 0.8817 - val_accuracy: 0.5834
# Epoch 8/20
# 126/126 [==============================] - 5s 43ms/step - loss: 1.0710 - accuracy: 0.4483 - val_loss: 1.0627 - val_accuracy: 0.4520
# Epoch 5/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0708 - accuracy: 0.4483 - val_loss: 1.0632 - val_accuracy: 0.4520
# Epoch 6/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0704 - accuracy: 0.4483 - val_loss: 1.0623 - val_accuracy: 0.4520
# Epoch 7/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0704 - accuracy: 0.4483 - val_loss: 1.0638 - val_accuracy: 0.4520
# Epoch 8/20
# 126/126 [==============================] - 5s 43ms/step - loss: 1.0703 - accuracy: 0.4483 - val_loss: 1.0640 - val_accuracy: 0.4520
# Epoch 9/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0698 - accuracy: 0.4483 - val_loss: 1.0650 - val_accuracy: 0.4520
# Epoch 10/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0691 - accuracy: 0.4483 - val_loss: 1.0627 - val_accuracy: 0.4520
# Epoch 11/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0694 - accuracy: 0.4483 - val_loss: 1.0636 - val_accuracy: 0.4520
# Epoch 12/20
# 126/126 [==============================] - 5s 43ms/step - loss: 1.0697 - accuracy: 0.4483 - val_loss: 1.0645 - val_accuracy: 0.4520
# Epoch 13/20
# 126/126 [==============================] - 6s 45ms/step - loss: 1.0695 - accuracy: 0.4483 - val_loss: 1.0638 - val_accuracy: 0.4520
# Epoch 14/20
# 126/126 [==============================] - 5s 43ms/step - loss: 1.0684 - accuracy: 0.4483 - val_loss: 1.0642 - val_accuracy: 0.4520
# Epoch 15/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0690 - accuracy: 0.4483 - val_loss: 1.0622 - val_accuracy: 0.4520
# Epoch 16/20
# 126/126 [==============================] - 5s 42ms/step - loss: 1.0685 - accuracy: 0.4483 - val_loss: 1.0623 - val_accuracy: 0.4520
# Epoch 17/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0684 - accuracy: 0.4483 - val_loss: 1.0610 - val_accuracy: 0.4520
# Epoch 18/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0641 - accuracy: 0.4474 - val_loss: 1.0497 - val_accuracy: 0.4523
# Epoch 19/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0493 - accuracy: 0.4562 - val_loss: 1.0302 - val_accuracy: 0.4695
# Epoch 20/20
# 126/126 [==============================] - 5s 41ms/step - loss: 1.0377 - accuracy: 0.4709 - val_loss: 1.0142 - val_accuracy: 0.4900
# Model  1 6
# Epoch 1/20
# 126/126 [==============================] - 8s 60ms/step - loss: 1.0515 - accuracy: 0.4593 - val_loss: 0.9994 - val_accuracy: 0.5137
# Epoch 2/20
# 126/126 [==============================] - 8s 61ms/step - loss: 0.9789 - accuracy: 0.5259 - val_loss: 0.9087 - val_accuracy: 0.5989
# Epoch 3/20
# 126/126 [==============================] - 7s 59ms/step - loss: 0.9028 - accuracy: 0.5744 - val_loss: 0.8923 - val_accuracy: 0.5807
# Epoch 4/20
# 126/126 [==============================] - 8s 60ms/step - loss: 0.8551 - accuracy: 0.6015 - val_loss: 0.7820 - val_accuracy: 0.6394
# Epoch 5/20
# 126/126 [==============================] - 7s 58ms/step - loss: 0
# Epoch 6/20
# 126/126 [==============================] - 8s 64ms/step - loss: 1.0493 - accuracy: 0.4569 - val_loss: 1.0356 - val_accuracy: 0.4748
# Epoch 7/20
# 126/126 [==============================] - 8s 65ms/step - loss: 1.0372 - accuracy: 0.4737 - val_loss: 1.0076 - val_accuracy: 0.4920
# Epoch 8/20
# 126/126 [==============================] - 8s 63ms/step - loss: 1.0159 - accuracy: 0.4933 - val_loss: 0.9856 - val_accuracy: 0.5197
# Epoch 9/20
# 126/126 [==============================] - 8s 62ms/step - loss: 1.0006 - accuracy: 0.5100 - val_loss: 0.9595 - val_accuracy: 0.5425
# Epoch 10/20
# 126/126 [==============================] - 8s 63ms/step - loss: 0.9843 - accuracy: 0.5231 - val_loss: 0.9551 - val_accuracy: 0.5392
# Epoch 11/20
# 126/126 [==============================] - 8s 64ms/step - loss: 0.9701 - accuracy: 0.5301 - val_loss: 0.9429 - val_accuracy: 0.5475
# Epoch 12/20
# 126/126 [==============================] - 8s 62ms/step - loss: 0.9613 - accuracy: 0.5412 - val_loss: 0.9244 - val_accuracy: 0.5697
# Epoch 13/20
# 126/126 [==============================] - 8s 64ms/step - loss: 0.9483 - accuracy: 0.5426 - val_loss: 0.9108 - val_accuracy: 0.5674
# Epoch 14/20
# 126/126 [==============================] - 8s 63ms/step - loss: 0.9309 - accuracy: 0.5546 - val_loss: 0.8955 - val_accuracy: 0.5887
# Epoch 15/20
# 126/126 [==============================] - 8s 63ms/step - loss: 0.9231 - accuracy: 0.5586 - val_loss: 0.8919 - val_accuracy: 0.5874
# Epoch 16/20
# 126/126 [==============================] - 8s 62ms/step - loss: 0.9126 - accuracy: 0.5657 - val_loss: 0.8802 - val_accuracy: 0.5897
# Epoch 17/20
# 126/126 [==============================] - 8s 62ms/step - loss: 0.9015 - accuracy: 0.5747 - val_loss: 0.8616 - val_accuracy: 0.5957
# Epoch 18/20
# 126/126 [==============================] - 8s 62ms/step - loss: 0.8904 - accuracy: 0.5742 - val_loss: 0.8524 - val_accuracy: 0.6016
# Epoch 19/20
# 126/126 [==============================] - 8s 63ms/step - loss: 0.8769 - accuracy: 0.5874 - val_loss: 0.8514 - val_accuracy: 0.6069
# Epoch 20/20
# 126/126 [==============================] - 8s 64ms/step - loss: 0.8708 - accuracy: 0.5924 - val_loss: 0.8452 - val_accuracy: 0.6139
# Model  2 0
# Epoch 1/20
# 126/126 [==============================] - 3s 18ms/step - loss: 1.0608 - accuracy: 0.4521 - val_loss: 1.0519 - val_accuracy: 0.4700
# Epoch 2/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0272 - accuracy: 0.4819 - val_loss: 1.0135 - val_accuracy: 0.4880
# Epoch 3/20
# 126/126 [==============================] - 2s 16ms/step - loss: 0.9917 - accuracy: 0.5173 - val_loss: 0.9666 - val_accuracy: 0.5392
# Epoch 4/20
# 126/126 [==============================] - 2s 16ms/step - loss: 0.9676 - accuracy: 0.5386 - val_loss: 0.9408 - val_accuracy: 0.5445
# Epoch 5/20
# 126/126 [==============================] - 2s 16ms/step - loss: 0
# 126/126 [==============================] - 3s 28ms/step - loss: 1.0033 - accuracy: 0.5070 - val_loss: 0.9889 - val_accuracy: 0.5160
# Epoch 12/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9934 - accuracy: 0.5131 - val_loss: 0.9784 - val_accuracy: 0.5222
# Epoch 13/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9842 - accuracy: 0.5236 - val_loss: 0.9675 - val_accuracy: 0.5382
# Epoch 14/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9763 - accuracy: 0.5256 - val_loss: 0.9594 - val_accuracy: 0.5425
# Epoch 15/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9611 - accuracy: 0.5371 - val_loss: 0.9477 - val_accuracy: 0.5432
# Epoch 16/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9528 - accuracy: 0.5452 - val_loss: 0.9402 - val_accuracy: 0.5480
# Epoch 17/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9426 - accuracy: 0.5477 - val_loss: 0.9280 - val_accuracy: 0.5567
# Epoch 18/20
# 126/126 [==============================] - 3s 28ms/step - loss: 0.9320 - accuracy: 0.5519 - val_loss: 0.9162 - val_accuracy: 0.5622
# Epoch 19/20
# 126/126 [==============================] - 3s 27ms/step - loss: 0.9227 - accuracy: 0.5605 - val_loss: 0.9075 - val_accuracy: 0.5634
# Epoch 20/20
# 126/126 [==============================] - 4s 28ms/step - loss: 0.9134 - accuracy: 0.5672 - val_loss: 0.9042 - val_accuracy: 0.5639
# Model  2 4
# Epoch 1/20
# 126/126 [==============================] - 2s 13ms/step - loss: 1.0681 - accuracy: 0.4496 - val_loss: 1.0859 - val_accuracy: 0.4515
# Epoch 2/20
# 126/126 [==============================] - 2s 13ms/step - loss: 1.0624 - accuracy: 0.4539 - val_loss: 1.0658 - val_accuracy: 0.4473
# Epoch 3/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0521 - accuracy: 0.4591 - val_loss: 1.0511 - val_accuracy: 0.4703
# Epoch 4/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0433 - accuracy: 0.4692 - val_loss: 1.0426 - val_accuracy: 0.4733
# Epoch 5/20
# 126/126 [==============================] - 2s 16ms/step - loss: 1.0363 - accuracy: 0.4787 - val_loss: 1.0283 - val_accuracy: 0.4835
# Epoch 6/20
# 126/126 [==============================] - 2s 12ms/step - loss: 1.0282 - accuracy: 0.4830 - val_loss: 1.0190 - val_accuracy: 0.4883
# Epoch 7/20
# 126/126 [==============================] - 2s 13ms/step - loss: 1.0212 - accuracy: 0.4901 - val_loss: 1.0100 - val_accuracy: 0.4938
# Epoch 8/20
# 126/126 [==============================] - 2s 13ms/step - loss: 1.0097 - accuracy: 0.4992 - val_loss: 0.9924 - val_accuracy: 0.5045
# Epoch 9/20
# 126/126 [==============================] - 2s 12ms/step - loss: 1.0035 - accuracy: 0.5040 - val_loss: 0.9853 - val_accuracy: 0.5082
# Epoch 10/20
# 126/126 [==============================] - 2s 17ms/step - loss: 0.9919 - accuracy: 0.5116 - val_loss: 0.9675 - val_accuracy: 0.5275
# Epoch 11/20
# 126/126 [==============================] - 2s 13ms/step - loss: 0.9834 - accuracy: 0.5240 - val_loss: 0.9651 - val_accuracy: 0.5262
# Epoch 12/20
# 126/126 [==============================] - 2s 13ms/step - loss: 0.9750 - accuracy: 0.5261 - val_loss: 0.9527 - val_accuracy: 0.5352
# Epoch 13/20
# 126/126 [==============================] - 2s 12ms/step - loss: 0.9659 - accuracy: 0.5333 - val_loss: 0.9340 - val_accuracy: 0.5492
# Epoch 14/20
# 126/126 [==============================] - 2s 17ms/step - loss: 0
20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0823 - accuracy: 0.4350 - val_loss: 1.0739 - val_accuracy: 0.4403
# Epoch 3/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0710 - accuracy: 0.4464 - val_loss: 1.0717 - val_accuracy: 0.4403
# Epoch 4/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0705 - accuracy: 0.4509 - val_loss: 1.0719 - val_accuracy: 0.4403
# Epoch 5/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0678 - accuracy: 0.4510 - val_loss: 1.0734 - val_accuracy: 0.4403
# Epoch 6/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0680 - accuracy: 0.4512 - val_loss: 1.0715 - val_accuracy: 0.4403
# Epoch 7/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0679 - accuracy: 0.4512 - val_loss: 1.0700 - val_accuracy: 0.4403
# Epoch 8/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0651 - accuracy: 0.4513 - val_loss: 1.0648 - val_accuracy: 0.4403
# Epoch 9/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0591 - accuracy: 0.4546 - val_loss: 1.0541 - val_accuracy: 0.4496
# Epoch 10/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0495 - accuracy: 0.4613 - val_loss: 1.0476 - val_accuracy: 0.4603
# Epoch 11/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0477 - accuracy: 0.4628 - val_loss: 1.0428 - val_accuracy: 0.4580
# Epoch 12/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0427 - accuracy: 0.4694 - val_loss: 1.0398 - val_accuracy: 0.4633
# Epoch 13/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0399 - accuracy: 0.4684 - val_loss: 1.0400 - val_accuracy: 0.4643
# Epoch 14/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0362 - accuracy: 0.4754 - val_loss: 1.0294 - val_accuracy: 0.4800
# Epoch 15/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0304 - accuracy: 0.4809 - val_loss: 1.0223 - val_accuracy: 0.4823
# Epoch 16/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0267 - accuracy: 0.4821 - val_loss: 1.0156 - val_accuracy: 0.4978
# Epoch 17/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0194 - accuracy: 0.4897 - val_loss: 1.0034 - val_accuracy: 0.5055
# Epoch 18/20
# 126/126 [==============================] - 2s 18ms/step - loss: 1.0106 - accuracy: 0.4993 - val_loss: 0.9945 - val_accuracy: 0.5125
# Epoch 19/20
# 126/126 [==============================] - 2s 17ms/step - loss: 1.0021 - accuracy: 0.5078 - val_loss: 0.9862 - val_accuracy: 0.5170
# Epoch 20/20
# 126/126 [==============================] - 2s 17ms/step - loss: 0.9956 - accuracy: 0.5142 - val_loss: 0.9861 - val_accuracy: 0.5095

# %%
## print the accuracies and times obtained
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (8,8))

ax1.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in accuracies for x in sublist], color='blue', marker='.')
ax1.set_title('Accuracies')
ax1.set_xlabel('Model')
ax1.set_ylabel('Accuracy')

ax2.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in times for x in sublist], color='orange', marker='.')
ax2.set_title('Times')
ax2.set_xlabel('Model')
ax2.set_ylabel('Time(s)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate the models

# %%
acc = 0
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        score = modelsTams[i][j].evaluate(train_test_conditioned[i][1], train_test_conditioned[i][3], verbose=0)
        print("Test accuracy: ", score[1])
        if(score[1] > acc):
            acc = score[1]
            best_i = i
            best_j = j
print("Best model ", best_i, best_j)
# Out:
# Model  0 0
# Test accuracy:  0.6418581604957581
# Model  0 1
# Test accuracy:  0.44955044984817505
# Model  0 2
# Test accuracy:  0.6698301434516907
# Model  0 3
# Test accuracy:  0.44955044984817505
# Model  0 4
# Test accuracy:  0.6623376607894897
# Model  0 5
# Test accuracy:  0.5494505763053894
# Model  0 6
# Test accuracy:  0.7220279574394226
# Model  0 7
# Test accuracy:  0.44955044984817505
# Model  1 0
# Test accuracy:  0.6970529556274414
# Model  1 1
# Test accuracy:  0.5509490370750427
# Model  1 2
# Test accuracy:  0.703046977519989
# Model  1 3
# Test accuracy:  0.5991508364677429
# Model  1 4
# Test accuracy:  0.6830669045448303
# Model  1 5
# Test accuracy:  0.49000999331474304
# Model  1 6
# Test accuracy:  0.730269730091095
# Model  1 7
# Test accuracy:  0.6138861179351807
# Model  2 0
# Test accuracy:  0.6625874042510986
# Model  2 1
# Test accuracy:  0.4872627258300781
# Model  2 2
# Test accuracy:  0.6615884304046631
# Model  2 3
# Test accuracy:  0.5639360547065735
# Model  2 4
# Test accuracy:  0.5814185738563538
# Model  2 5
# Test accuracy:  0.44030970335006714
# Model  2 6
# Test accuracy:  0.6383616328239441
# Model  2 7
# Test accuracy:  0.5094904899597168
# Best model  1 6

# %%
# Visualize the summary of the best model
activation_function = modelsTams[best_i][best_j].layers[1].activation
kernel_size = modelsTams[best_i][best_j].layers[1].kernel_size
pool_size = modelsTams[best_i][best_j].layers[2].pool_size

print("Input size:", tams_L[best_i])
print("Activation function: ", activation_function)
print("Kernel size: ", kernel_size)
print("Pool size: ", pool_size)
# Out:
# Input size: (48, 48)
# Activation function:  <function relu at 0x00000229782A6AC0>
# Kernel size:  (6, 6)
# Pool size:  (3, 3)

# %% [markdown]
# ## Save the best model

# %%
model_pkl_file = "./CNN_classifier_fer3.pkl"

with open(model_pkl_file, 'wb') as file:
    pickle.dump(modelsTams[best_i][best_j], file)

# %% [markdown]
# ## Visualize the confusion matrix of each model

# %%
#process the real classes for the confusion matrix
y_real = list()
for i in range(0, len(tams_L)):
    instances = train_test_conditioned[i][3]
    y_instance = list()
    for k in range (0, len(instances)):
        y_instance.append(decode(instances[k]))
    y_real.append(y_instance)

# %%
for i in range(0, len(tams_L)):
    #size of the data used
    l = list(tams_L[i]) #original size
    l[0], l[1] = l[1], l[0] #transpose
    l.append(1)
    l = (1,) + tuple(l)
    instances = train_test_conditioned[i][1] #test data
    for j in range (0, len(modelsTams[i])):
        predictions_j = list()
        for k in range (0, len(instances)):
            predictions_j.append(numeric_to_class(modelsTams[i][j](instances[k].reshape(l)).numpy().argmax(axis=1)[0]))
        print("model: ", i, j)
        #confusion matrix
        cm = confusion_matrix(y_real[i], predictions_j, labels=['angry', 'happy','sad'])
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['angry', 'happy','sad'])
        disp.plot()
        plt.show()
# Out:
# model:  0 0
# model:  0 1
# model:  0 2
# model:  0 3
# model:  0 4
# model:  0 5
# model:  0 6
# model:  0 7
# model:  1 0
# model:  1 1
# model:  1 2
# model:  1 3
# model:  1 4
# model:  1 5
# model:  1 6
# model:  1 7
# model:  2 0
# model:  2 1
# model:  2 2
# model:  2 3
# model:  2 4
# model:  2 5
# model:  2 6
# model:  2 7
