# %% [markdown]
# ## 1) Importación de librerías necesarias

# %%
import pandas as pd
import os
import numpy as np
from PIL import Image
import pickle
import time
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation, Conv2D, Dense, Dropout
from tensorflow.keras.layers import Flatten, Input, Reshape, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
RANDOM_STATE=333

# %% [markdown]
# ## 2) Funciones que se van a usar

# %%
"""
Given the main directory of the location of the images, the URL of each image is loaded to a dataframe with his clasification
"""
def loadData(path_main_directory):
    paths_list = list()
    label_list = list()

    for subdirectory in os.listdir(path_main_directory):
        #Build the path of every subdirectory of the main_directory
        path_subdirectory = os.path.join(path_main_directory, subdirectory)

        #Iterate over all the images of the subdirectory adding the path to the dictionary
        for image_name in os.listdir(path_subdirectory):
            image_path = os.path.join(path_subdirectory, image_name)
            paths_list.append(image_path)
            label_list.append(subdirectory)

        init_data_dict = {'path' : paths_list, 'label' : label_list}

    return pd.DataFrame(init_data_dict)

# %%
"""
Given the URL of the images as a list, the information of the size of the images is returned as a dataframe
"""
def getImageSizeInfo(images_path_L):
    #list of the size of each image
    images_size_L = list()
    #List of the width of each image
    images_width_L = list()
    #List of the height of each image
    images_height_L = list()
    #List of the ratio of the size of each image
    images_ratio_L = list()

    for path in images_path_L:
        image = Image.open(path)
        #Get the size of an image (given as a tuple) and append it to the list
        images_size_L.append(image.size)
        #Get the size of the image and append it to the list
        images_width_L.append(image.size[0])
        #Get the height of the image and append it to the list
        images_height_L.append(image.size[1])
        #Get the ratio (width/height) of the image and append it to the list
        images_ratio_L.append(round(image.size[0] / image.size[1], 2))

    #Dictionary with all the information
    image_info_D = {'path' : images_path_L, 'size' : images_size_L, 'width' : images_width_L, 'height' : images_height_L,'ratio' : images_ratio_L}
    #Data frame with all the information
    return pd.DataFrame(image_info_D)

# %%
"""
Given the number of sizes that the images want to be resized to returns a list with the sizes
"""
def getSizes(numMult):

    mult_L = [*np.arange(0 + 1/numMult, 1 + 1/numMult, 1/numMult)]
    tams_L = list()

    for mult in mult_L:
        tams_L.append((int(mult * image_info_DF['width'].mean()),int(mult * image_info_DF['height'].mean())))

    return tams_L

# %%
def loadImages(tams_L, images_path_L, images_class_L):
    images_BW_D = dict()

    for i in range(0, len(tams_L)):
        #List of the representation of the images in black and white as a list
        imgs_BW_L = list()
        #List of the class of each image
        class_BW_L = list()

        for j in range(0, len(images_path_L)):
            #Open image and resize it
            img = Image.open(images_path_L[j]).resize(tams_L[i])
            #Image in black and white
            img = img.convert('L')
            #Image as a list
            arr = np.asarray(img, dtype = np.int_).flatten()
            
            imgs_BW_L.append(arr)
            class_BW_L.append(images_class_L[j])

        images_BW_D[i] = (imgs_BW_L, class_BW_L)
    
    return images_BW_D

# %%
"""
Given the name of the class, returns the associated numeric class
"""
def class_to_numeric(class_list):
    l = list()
    for i in range (0, len(class_list)):
        if(class_list[i] == 'angry'):
            l.append(0)
        elif(class_list[i] == 'happy'):
            l.append(1)
        elif(class_list[i] == 'sad'):
            l.append(2)
    return np.array(l)

# %%
def numeric_to_class(type):
    if(type == 0):
        return 'angry'
    elif(type == 1):
        return 'happy'
    else:
        return 'sad'

# %%
def decode(class_list):
    if(class_list[0] == 1):
        return 'angry'
    elif(class_list[1] == 1):
        return 'happy'
    else:
        return 'sad'

# %%
def createModel(num_layers, act, aph):
    mlp = MLPClassifier(hidden_layer_sizes=(num_layers, ), activation=act, solver='adam', alpha=aph, batch_size='auto',
                learning_rate_init=0.001, max_iter=1000, random_state=RANDOM_STATE)
    return mlp

# %% [markdown]
# ## 2) Carga del conjunto de datos

# %% [markdown]
# Se van a cargar las URL de las imágenes en un dataframe junto a su clasificación.
#
# El directorio principal está divido en 3 subdirectorios titulados: angry, happy y sad. Por lo que todas las URLs (imágenes) de un directorio tendrán esa clasificación.

# %%
#Main directory of the data
path_main_directory = './initialDataset3'

#Load the data
init_data_df = loadData(path_main_directory)

display(init_data_df.head())
display(init_data_df.tail())
# Out:
#                                                 path  label
# 0  ./initialDataset3\angry\0346f330983a068db0633f...  angry
# 1  ./initialDataset3\angry\118-1183761_angry-pers...  angry
# 2  ./initialDataset3\angry\118-1183847_angry-pers...  angry
# 3  ./initialDataset3\angry\139-1393790_angry-pers...  angry
# 4                ./initialDataset3\angry\1564075.jpg  angry
#                                                   path label
# 260  ./initialDataset3\sad\vector-sad-man-sitting-s...   sad
# 261  ./initialDataset3\sad\very-sad-man-sitting-alo...   sad
# 262  ./initialDataset3\sad\what-successful-people-d...   sad
# 263  ./initialDataset3\sad\what-to-say-to-someone-w...   sad
# 264  ./initialDataset3\sad\_2539df08-4f50-11e6-85e3...   sad

# %% [markdown]
# Se calculan el número de ejemplos de cada clase

# %%
init_data_df['label'].value_counts()
# Out:
# label
# happy    100
# angry     86
# sad       79
# Name: count, dtype: int64

# %% [markdown]
# Y se calcula la frecuencia de cada clase

# %%
init_data_df['label'].value_counts() / init_data_df['label'].count() * 100
# Out:
# label
# happy    37.735849
# angry    32.452830
# sad      29.811321
# Name: count, dtype: float64

# %% [markdown]
# Como se puede ver, la cantidad de datos de cada clase es muy similar, lo cual es una ventaja para entrenar el modelo.

# %% [markdown]
# ## 3) Adaptación del formato de las imágenes

# %% [markdown]
# ### Elección del tamaño:
#
#   La elección del tamaño es muy importante, ya que tendrá efecto en el tiempo de entrenamiento del modelo y en la precisión del mismo. Aunque el tamaño de las imágenes del conjunto de datos elegido sea (48x48), se explorarán otros tamaños para evaluar los modelos con distintas características.

# %% [markdown]
# Se saca la información del tamaño de las imágenes y se guarda en un data frame

# %%
image_info_DF = getImageSizeInfo(init_data_df['path'].values)
display(image_info_DF.head())
# Out:
#                                                 path          size  width  \
# 0  ./initialDataset3\angry\0346f330983a068db0633f...    (700, 701)    700
# 1  ./initialDataset3\angry\118-1183761_angry-pers...    (820, 558)    820
# 2  ./initialDataset3\angry\118-1183847_angry-pers...    (820, 501)    820
# 3  ./initialDataset3\angry\139-1393790_angry-pers...    (320, 320)    320
# 4                ./initialDataset3\angry\1564075.jpg  (1920, 1200)   1920
#
#    height  ratio
# 0     701   1.00
# 1     558   1.47
# 2     501   1.64
# 3     320   1.00
# 4    1200   1.60

# %% [markdown]
# se muestra la resolución de las imágenes

# %%
fig = plt.figure(figsize = (4,4))
ax = fig.add_subplot(111)
points = ax.scatter(image_info_DF.width, image_info_DF.height, color = 'blue', marker='.')
ax.set_title("Image Resolution")
ax.set_xlabel("Width", size=14)
ax.set_ylabel("Height", size=14)
# Out:
# Text(0, 0.5, 'Height')

# %% [markdown]
# como se puede ver, son imágenes con resoluciones muy altas

# %%
image_info_DF.describe().transpose()
# Out:
#         count         mean         std    min     25%    50%      75%      max
# width   265.0  1152.584906  952.422904  220.0  626.00  900.0  1300.00  6016.00
# height  265.0   809.928302  729.307963  154.0  405.00  605.0   915.00  5604.00
# ratio   265.0     1.516717    0.413742    0.5    1.33    1.5     1.78     3.48

# %% [markdown]
# Se van a probar con distintos tamaños (todos ellos dependiendientes de la anchura y altura original)

# %%
numMult = 3
tams_L = getSizes(numMult)
tams_L.append((96, 96))
tams_L.append((48, 48))
tams_L.append((24, 24))
tams_L
# Out:
# [(384, 269), (768, 539), (1152, 809), (96, 96), (48, 48), (24, 24)]

# %% [markdown]
# # Pruebas nuevas tamaños

# %% [markdown]
# Se van a generar varios conjuntos de datos: cada uno de ellos contendrá las imágenes en blanco y negro con distintos tamaños.

# %%
load_images  = loadImages(tams_L, init_data_df['path'].values, init_data_df['label'].values)

# %% [markdown]
# Se ve la forma de cada uno de los conjuntos de datos

# %%
for i in range(0, len(tams_L)):
    print(np.array(load_images[i][0]).shape)
    print(np.array(load_images[i][1]).shape)
# Out:
# (265, 103296)
# (265,)
# (265, 413952)
# (265,)
# (265, 931968)
# (265,)
# (265, 9216)
# (265,)
# (265, 2304)
# (265,)
# (265, 576)
# (265,)

# %% [markdown]
# Se visualiza una imagen de prueba para ver los cambios realizados tras redimensionar

# %%
print("Clase: ", load_images[0][1][1])
for i in range (0, len(tams_L)):
    l = list(tams_L[i])
    l[0], l[1] = l[1], l[0] #transpose
    image = Image.fromarray(load_images[i][0][0].reshape(tuple(l)).astype(np.uint8))
    plt.imshow(image)
    plt.show()
# Out:
# Clase:  angry

# %%
#Dictionary with the train test splits for all the representations
load_train_test = dict()
for i in range(0, len(tams_L)):
    X_train, X_test, y_train, y_test = train_test_split(load_images[i][0], load_images[i][1], test_size=0.2,shuffle=True)
    load_train_test[i] = (np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test))
    print('X_train shape:', np.array(X_train).shape, 'y_train shape:', np.array(y_train).shape, 'X_test shape:', np.array(X_test).shape, 'y_test shape:', np.array(y_test).shape)
# Out:
# X_train shape: (212, 103296) y_train shape: (212,) X_test shape: (53, 103296) y_test shape: (53,)
# X_train shape: (212, 413952) y_train shape: (212,) X_test shape: (53, 413952) y_test shape: (53,)
# X_train shape: (212, 931968) y_train shape: (212,) X_test shape: (53, 931968) y_test shape: (53,)
# X_train shape: (212, 9216) y_train shape: (212,) X_test shape: (53, 9216) y_test shape: (53,)
# X_train shape: (212, 2304) y_train shape: (212,) X_test shape: (53, 2304) y_test shape: (53,)
# X_train shape: (212, 576) y_train shape: (212,) X_test shape: (53, 576) y_test shape: (53,)

# %%
#create a model for each image size, activation function, kernel size and pooling size
alpha_params_L = np.arange(0.01, 1.6, step=0.5)
activations_functions_L = ['relu', 'logistic']

modelsTams = dict()
for i in range(0, len(tams_L)):
    models = dict()
    j=0
    for aph in alpha_params_L:
        for num_layers in range(150, 250, 50):
            for act in activations_functions_L:
                model = createModel(num_layers, act, aph);
                models[j] = model
                j += 1
    modelsTams[i] = models

# %%
#print the summary of each model
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        print(modelsTams[i][j].hidden_layer_sizes)
        print(modelsTams[i][j].activation)
        print(modelsTams[i][j].alpha)
# Out:
# Model  0 0
# (150,)
# relu
# 0.01
# Model  0 1
# (150,)
# logistic
# 0.01
# Model  0 2
# (200,)
# relu
# 0.01
# Model  0 3
# (200,)
# logistic
# 0.01
# Model  0 4
# (150,)
# relu
# 0.51
# Model  0 5
# (150,)
# logistic
# 0.51
# Model  0 6
# (200,)
# relu
# 0.51
# Model  0 7
# (200,)
# logistic
# 0.51
# Model  0 8
# (150,)
# relu
# 1.01
# Model  0 9
# (150,)
# logistic
# 1.01
# Model  0 10
# (200,)
# relu
# 1.01
# Model  0 11
# (200,)
# logistic
# 1.01
# Model  0 12
# (150,)
# relu
# 1.51
# Model  0 13
# (150,)
# logistic
# 1.51
# Model  0 14
# (200,)
# relu
# 1.51
# Model  0 15
# (200,)
# logistic
# 1.51
# Model  1 0
# (150,)
# relu
# 0.01
# Model  1 1
# (150,)
# logistic
# 0.01
# Model  1 2
# (200,)
# relu
# 0.01
# Model  1 3
# (200,)
# logistic
# 0.01
# Model  1 4
# (150,)
# relu
# 0.51
# Model  1 5
# (150,)
# logistic
# 0.51
# Model  1 6
# (200,)
# relu
# 0.51
# Model  1 7
# (200,)
# logistic
# 0.51
# Model  1 8
# (150,)
# relu
# 1.01
# Model  1 9
# (150,)
# logistic
# 1.01
# Model  1 10
# (200,)
# relu
# 1.01
# Model  1 11
# (200,)
# logistic
# 1.01
# Model  1 12
# (150,)
# relu
# 1.51
# Model  1 13
# (150,)
# logistic
# 1.51
# Model  1 14
# (200,)
# relu
# 1.51
# Model  1 15
# (200,)
# logistic
# 1.51
# Model  2 0
# (150,)
# relu
# 0.01
# Model  2 1
# (150,)
# logistic
# 0.01
# Model  2 2
# (200,)
# relu
# 0.01
# Model  2 3
# (200,)
# logistic
# 0.01
# Model  2 4
# (150,)
# relu
# 0.51
# Model  2 5
# (150,)
# logistic
# 0.51
# Model  2 6
# (200,)
# relu
# 0.51
# Model  2 7
# (200,)
# logistic
# 0.51
# Model  2 8
# (150,)
# relu
# 1.01
# Model  2 9
# (150,)
# logistic
# 1.01
# Model  2 10
# (200,)
# relu
# 1.01
# Model  2 11
# (200,)
# logistic
# 1.01
# Model  2 12
# (150,)
# relu
# 1.51
# Model  2 13
# (150,)
# logistic
# 1.51
# Model  2 14
# (200,)
# relu
# 1.51
# Model  2 15
# (200,)
# logistic
# 1.51
# Model  3 0
# (150,)
# relu
# 0.01
# Model  3 1
# (150,)
# logistic
# 0.01
# Model  3 2
# (200,)
# relu
# 0.01
# Model  3 3
# (200,)
# logistic
# 0.01
# Model  3 4
# (150,)
# relu
# 0.51
# Model  3 5
# (150,)
# logistic
# 0.51
# Model  3 6
# (200,)
# relu
# 0.51
# Model  3 7
# (200,)
# logistic
# 0.51
# Model  3 8
# (150,)
# relu
# 1.01
# Model  3 9
# (150,)
# logistic
# 1.01
# Model  3 10
# (200,)
# relu
# 1.01
# Model  3 11
# (200,)
# logistic
# 1.01
# Model  3 12
# (150,)
# relu
# 1.51
# Model  3 13
# (150,)
# logistic
# 1.51
# Model  3 14
# (200,)
# relu
# 1.51
# Model  3 15
# (200,)
# logistic
# 1.51
# Model  4 0
# (150,)
# relu
# 0.01
# Model  4 1
# (150,)
# logistic
# 0.01
# Model  4 2
# (200,)
# relu
# 0.01
# Model  4 3
# (200,)
# logistic
# 0.01
# Model  4 4
# (150,)
# relu
# 0.51
# Model  4 5
# (150,)
# logistic
# 0.51
# Model  4 6
# (200,)
# relu
# 0.51
# Model  4 7
# (200,)
# logistic
# 0.51
# Model  4 8
# (150,)
# relu
# 1.01
# Model  4 9
# (150,)
# logistic
# 1.01
# Model  4 10
# (200,)
# relu
# 1.01
# Model  4 11
# (200,)
# logistic
# 1.01
# Model  4 12
# (150,)
# relu
# 1.51
# Model  4 13
# (150,)
# logistic
# 1.51
# Model  4 14
# (200,)
# relu
# 1.51
# Model  4 15
# (200,)
# logistic
# 1.51
# Model  5 0
# (150,)
# relu
# 0.01
# Model  5 1
# (150,)
# logistic
# 0.01
# Model  5 2
# (200,)
# relu
# 0.01
# Model  5 3
# (200,)
# logistic
# 0.01
# Model  5 4
# (150,)
# relu
# 0.51
# Model  5 5
# (150,)
# logistic
# 0.51
# Model  5 6
# (200,)
# relu
# 0.51
# Model  5 7
# (200,)
# logistic
# 0.51
# Model  5 8
# (150,)
# relu
# 1.01
# Model  5 9
# (150,)
# logistic
# 1.01
# Model  5 10
# (200,)
# relu
# 1.01
# Model  5 11
# (200,)
# logistic
# 1.01
# Model  5 12
# (150,)
# relu
# 1.51
# Model  5 13
# (150,)
# logistic
# 1.51
# Model  5 14
# (200,)
# relu
# 1.51
# Model  5 15
# (200,)
# logistic
# 1.51

# %%
#data conditioning for each model
train_test_conditioned = dict()

for i in range(0, len(tams_L)):
    X_train = load_train_test[i][0]
    X_train = X_train.astype('float32') / 255
    
    X_test = load_train_test[i][1]
    X_test = X_test.astype('float32') / 255
    
    y_train = load_train_test[i][2]
    y_train = class_to_numeric(y_train) # Converts the string class to numeric class
    y_train = to_categorical(y_train) # Converts the classes into one-hot-vector
    
    y_test = load_train_test[i][3]
    y_test = class_to_numeric(y_test) # Converts the string class to numeric class
    y_test = to_categorical(y_test) # Converts the classes into one-hot-vector

    print('X_train shape:', X_train.shape, 'X_test shape:', X_test.shape, 'y_train shape:', y_train.shape, 'y_test shape:', y_test.shape)
    
    train_test_conditioned[i] = (X_train, X_test, y_train, y_test)
# Out:
# X_train shape: (212, 103296) X_test shape: (53, 103296) y_train shape: (212, 3) y_test shape: (53, 3)
# X_train shape: (212, 413952) X_test shape: (53, 413952) y_train shape: (212, 3) y_test shape: (53, 3)
# X_train shape: (212, 931968) X_test shape: (53, 931968) y_train shape: (212, 3) y_test shape: (53, 3)
# X_train shape: (212, 9216) X_test shape: (53, 9216) y_train shape: (212, 3) y_test shape: (53, 3)
# X_train shape: (212, 2304) X_test shape: (53, 2304) y_train shape: (212, 3) y_test shape: (53, 3)
# X_train shape: (212, 576) X_test shape: (53, 576) y_train shape: (212, 3) y_test shape: (53, 3)

# %% [markdown]
# ## Train the models

# %%
#train the models
times = list()
accuracies = list()
for i in range(0, len(tams_L)):
    time_tam = list()
    accuracy_tam = list()
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        start = time.time()
        modelsTams[i][j].fit(train_test_conditioned[i][0], train_test_conditioned[i][2])
        stop = time.time()
        time_tam.append(stop-start)
        train_accuracy = modelsTams[i][j].score(train_test_conditioned[i][0], train_test_conditioned[i][2])
        print("Training score:", train_accuracy)
        accuracy_tam.append(train_accuracy)
    times.append(time_tam)
    accuracies.append(accuracy_tam)
# Out:
# Model  0 0
# Training score: 0.4339622641509434
# Model  0 1
# Training score: 0.0
# Model  0 2
# Training score: 0.3443396226415094
# Model  0 3
# Training score: 0.0
# Model  0 4
# Training score: 0.41037735849056606
# Model  0 5
# Training score: 0.0
# Model  0 6
# Training score: 0.49528301886792453
# Model  0 7
# Training score: 0.014150943396226415
# Model  0 8
# Training score: 0.33490566037735847
# Model  0 9
# Training score: 0.0
# Model  0 10
# Training score: 0.05188679245283019
# Model  0 11
# Training score: 0.009433962264150943
# Model  0 12
# Training score: 0.33490566037735847
# Model  0 13
# Training score: 0.0047169811320754715
# Model  0 14
# Training score: 0.4009433962264151
# Model  0 15
# Training score: 0.0047169811320754715
# Model  1 0
# Training score: 0.08490566037735849
# Model  1 1
# Training score: 0.0
# Model  1 2
# Training score: 0.23113207547169812
# Model  1 3
# Training score: 0.0
# Model  1 4
# Training score: 0.1509433962264151
# Model  1 5
# Training score: 0.0
# Model  1 6
# Training score: 0.08018867924528301
# Model  1 7
# Training score: 0.0
# Model  1 8
# Training score: 0.29245283018867924
# Model  1 9
# Training score: 0.0
# Model  1 10
# Training score: 0.05660377358490566
# Model  1 11
# Training score: 0.0047169811320754715
# Model  1 12
# Training score: 0.07547169811320754
# Model  1 13
# Training score: 0.0
# Model  1 14
# Training score: 0.08490566037735849
# Model  1 15
# Training score: 0.0047169811320754715
# Model  2 0
# Training score: 0.3443396226415094
# Model  2 1
# Training score: 0.0
# Model  2 2
# Training score: 0.33962264150943394
# Model  2 3
# Training score: 0.0
# Model  2 4
# Training score: 0.25943396226415094
# Model  2 5
# Training score: 0.0
# Model  2 6
# Training score: 0.25471698113207547
# Model  2 7
# Training score: 0.0
# Model  2 8
# Training score: 0.32547169811320753
# Model  2 9
# Training score: 0.0
# Model  2 10
# Training score: 0.24056603773584906
# Model  2 11
# Training score: 0.0047169811320754715
# Model  2 12
# Training score: 0.37264150943396224
# Model  2 13
# Training score: 0.0
# Model  2 14
# Training score: 0.12264150943396226
# Model  2 15
# Training score: 0.0
# Model  3 0
# Training score: 0.6839622641509434
# Model  3 1
# Training score: 0.4386792452830189
# Model  3 2
# Training score: 0.19811320754716982
# Model  3 3
# Training score: 0.0
# Model  3 4
# Training score: 0.589622641509434
# Model  3 5
# Training score: 0.06132075471698113
# Model  3 6
# Training score: 0.23113207547169812
# Model  3 7
# Training score: 0.05188679245283019
# Model  3 8
# Training score: 0.4481132075471698
# Model  3 9
# Training score: 0.009433962264150943
# Model  3 10
# Training score: 0.33490566037735847
# Model  3 11
# Training score: 0.09433962264150944
# Model  3 12
# Training score: 0.47641509433962265
# Model  3 13
# Training score: 0.2688679245283019
# Model  3 14
# Training score: 0.7122641509433962
# Model  3 15
# Training score: 0.08962264150943396
# Model  4 0
# Training score: 0.75
# Model  4 1
# Training score: 0.5188679245283019
# Model  4 2
# Training score: 0.8066037735849056
# Model  4 3
# Training score: 0.9622641509433962
# Model  4 4
# Training score: 0.6226415094339622
# Model  4 5
# Training score: 0.3632075471698113
# Model  4 6
# Training score: 0.8113207547169812
# Model  4 7
# Training score: 0.2358490566037736
# Model  4 8
# Training score: 0.44339622641509435
# Model  4 9
# Training score: 0.06132075471698113
# Model  4 10
# Training score: 0.6320754716981132
# Model  4 11
# Training score: 0.2641509433962264
# Model  4 12
# Training score: 0.5330188679245284
# Model  4 13
# Training score: 0.07547169811320754
# Model  4 14
# Training score: 0.32547169811320753
# Model  4 15
# Training score: 0.018867924528301886
# Model  5 0
# Training score: 0.5943396226415094
# Model  5 1
# Training score: 0.7075471698113207
# Model  5 2
# Training score: 0.9575471698113207
# Model  5 3
# Training score: 0.5660377358490566
# Model  5 4
# Training score: 0.5471698113207547
# Model  5 5
# Training score: 0.3443396226415094
# Model  5 6
# Training score: 0.5801886792452831
# Model  5 7
# Training score: 0.07075471698113207
# Model  5 8
# Training score: 0.6226415094339622
# Model  5 9
# Training score: 0.02358490566037736
# Model  5 10
# Training score: 0.5471698113207547
# Model  5 11
# Training score: 0.009433962264150943
# Model  5 12
# Training score: 0.5707547169811321
# Model  5 13
# Training score: 0.02830188679245283
# Model  5 14
# Training score: 0.3632075471698113
# Model  5 15
# Training score: 0.04716981132075472

# %%
## print the accuracies and times obtained
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (8,8))

ax1.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in accuracies for x in sublist], color='blue', marker='.')
ax1.set_title('Accuracies')
ax1.set_xlabel('Model')
ax1.set_ylabel('Accuracy')

ax2.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in times for x in sublist], color='orange', marker='.')
ax2.set_title('Times')
ax2.set_xlabel('Model')
ax2.set_ylabel('Time(s)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate the models

# %%
acc = 0
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        y_predict_test = modelsTams[i][j].predict(train_test_conditioned[i][1])
        score = accuracy_score(train_test_conditioned[i][3], y_predict_test)

        print("Test accuracy: ", score)
        if(score > acc):
            acc = score
            best_i = i
            best_j = j
print("Best model ", best_i, best_j)
# Out:
# Model  0 0
# Test accuracy:  0.22641509433962265
# Model  0 1
# Test accuracy:  0.0
# Model  0 2
# Test accuracy:  0.22641509433962265
# Model  0 3
# Test accuracy:  0.0
# Model  0 4
# Test accuracy:  0.2830188679245283
# Model  0 5
# Test accuracy:  0.0
# Model  0 6
# Test accuracy:  0.32075471698113206
# Model  0 7
# Test accuracy:  0.0
# Model  0 8
# Test accuracy:  0.22641509433962265
# Model  0 9
# Test accuracy:  0.0
# Model  0 10
# Test accuracy:  0.0
# Model  0 11
# Test accuracy:  0.0
# Model  0 12
# Test accuracy:  0.20754716981132076
# Model  0 13
# Test accuracy:  0.0
# Model  0 14
# Test accuracy:  0.3018867924528302
# Model  0 15
# Test accuracy:  0.0
# Model  1 0
# Test accuracy:  0.05660377358490566
# Model  1 1
# Test accuracy:  0.0
# Model  1 2
# Test accuracy:  0.18867924528301888
# Model  1 3
# Test accuracy:  0.0
# Model  1 4
# Test accuracy:  0.18867924528301888
# Model  1 5
# Test accuracy:  0.0
# Model  1 6
# Test accuracy:  0.09433962264150944
# Model  1 7
# Test accuracy:  0.0
# Model  1 8
# Test accuracy:  0.3018867924528302
# Model  1 9
# Test accuracy:  0.0
# Model  1 10
# Test accuracy:  0.05660377358490566
# Model  1 11
# Test accuracy:  0.0
# Model  1 12
# Test accuracy:  0.05660377358490566
# Model  1 13
# Test accuracy:  0.0
# Model  1 14
# Test accuracy:  0.05660377358490566
# Model  1 15
# Test accuracy:  0.0
# Model  2 0
# Test accuracy:  0.20754716981132076
# Model  2 1
# Test accuracy:  0.0
# Model  2 2
# Test accuracy:  0.18867924528301888
# Model  2 3
# Test accuracy:  0.0
# Model  2 4
# Test accuracy:  0.20754716981132076
# Model  2 5
# Test accuracy:  0.0
# Model  2 6
# Test accuracy:  0.1320754716981132
# Model  2 7
# Test accuracy:  0.0
# Model  2 8
# Test accuracy:  0.33962264150943394
# Model  2 9
# Test accuracy:  0.0
# Model  2 10
# Test accuracy:  0.22641509433962265
# Model  2 11
# Test accuracy:  0.018867924528301886
# Model  2 12
# Test accuracy:  0.33962264150943394
# Model  2 13
# Test accuracy:  0.0
# Model  2 14
# Test accuracy:  0.07547169811320754
# Model  2 15
# Test accuracy:  0.0
# Model  3 0
# Test accuracy:  0.22641509433962265
# Model  3 1
# Test accuracy:  0.1509433962264151
# Model  3 2
# Test accuracy:  0.11320754716981132
# Model  3 3
# Test accuracy:  0.0
# Model  3 4
# Test accuracy:  0.3584905660377358
# Model  3 5
# Test accuracy:  0.0
# Model  3 6
# Test accuracy:  0.18867924528301888
# Model  3 7
# Test accuracy:  0.018867924528301886
# Model  3 8
# Test accuracy:  0.16981132075471697
# Model  3 9
# Test accuracy:  0.0
# Model  3 10
# Test accuracy:  0.2641509433962264
# Model  3 11
# Test accuracy:  0.03773584905660377
# Model  3 12
# Test accuracy:  0.3018867924528302
# Model  3 13
# Test accuracy:  0.1320754716981132
# Model  3 14
# Test accuracy:  0.3018867924528302
# Model  3 15
# Test accuracy:  0.03773584905660377
# Model  4 0
# Test accuracy:  0.39622641509433965
# Model  4 1
# Test accuracy:  0.33962264150943394
# Model  4 2
# Test accuracy:  0.22641509433962265
# Model  4 3
# Test accuracy:  0.41509433962264153
# Model  4 4
# Test accuracy:  0.3584905660377358
# Model  4 5
# Test accuracy:  0.22641509433962265
# Model  4 6
# Test accuracy:  0.49056603773584906
# Model  4 7
# Test accuracy:  0.1320754716981132
# Model  4 8
# Test accuracy:  0.32075471698113206
# Model  4 9
# Test accuracy:  0.0
# Model  4 10
# Test accuracy:  0.3584905660377358
# Model  4 11
# Test accuracy:  0.18867924528301888
# Model  4 12
# Test accuracy:  0.32075471698113206
# Model  4 13
# Test accuracy:  0.05660377358490566
# Model  4 14
# Test accuracy:  0.16981132075471697
# Model  4 15
# Test accuracy:  0.05660377358490566
# Model  5 0
# Test accuracy:  0.18867924528301888
# Model  5 1
# Test accuracy:  0.20754716981132076
# Model  5 2
# Test accuracy:  0.32075471698113206
# Model  5 3
# Test accuracy:  0.24528301886792453
# Model  5 4
# Test accuracy:  0.3018867924528302
# Model  5 5
# Test accuracy:  0.18867924528301888
# Model  5 6
# Test accuracy:  0.2830188679245283
# Model  5 7
# Test accuracy:  0.0
# Model  5 8
# Test accuracy:  0.2830188679245283
# Model  5 9
# Test accuracy:  0.0
# Model  5 10
# Test accuracy:  0.18867924528301888
# Model  5 11
# Test accuracy:  0.0
# Model  5 12
# Test accuracy:  0.32075471698113206
# Model  5 13
# Test accuracy:  0.018867924528301886
# Model  5 14
# Test accuracy:  0.07547169811320754
# Model  5 15
# Test accuracy:  0.03773584905660377
# Best model  4 6

# %%
# Visualize the summary of the best model
activation_function = modelsTams[best_i][best_j].activation
hidden_layer_sizes = modelsTams[best_i][best_j].hidden_layer_sizes
alpha = modelsTams[best_i][best_j].alpha

print("Input size:", tams_L[best_i])
print("Activation function: ", activation_function)
print("Hidden layer sizes: ", hidden_layer_sizes)
print("Alpha: ", alpha)
# Out:
# Input size: (48, 48)
# Activation function:  relu
# Hidden layer sizes:  (200,)
# Alpha:  0.51

# %%
#Predict using the trained model against training dataset
y_predict_train = modelsTams[best_i][best_j].predict(train_test_conditioned[best_i][0])

#Predict using the trained model against test dataset
y_predict_test = modelsTams[best_i][best_j].predict(train_test_conditioned[best_i][1])

#Accuracy of the model for the train dataset
acc_train = accuracy_score(train_test_conditioned[best_i][2], y_predict_train)
#Clasification report for the train dataset
classif_rep_train = classification_report(train_test_conditioned[best_i][2], y_predict_train)

#Accuracy of the model for the test dataset
acc_test = accuracy_score(train_test_conditioned[best_i][3], y_predict_test)
#Clasification report for the train dataset
classif_rep_test = classification_report(train_test_conditioned[best_i][3], y_predict_test)
# Out:
# C:\Users\javie\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\javie\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#análisis para el dataset de entrenamiento
print('Precisión : ', acc_train)
print('Report : ')
print(classif_rep_train)
# Out:
# Precisión :  0.8113207547169812
# Report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        64
#            1       0.95      0.93      0.94        84
#            2       0.98      0.69      0.81        64
#
#    micro avg       0.94      0.83      0.88       212
#    macro avg       0.94      0.82      0.87       212
# weighted avg       0.94      0.83      0.88       212
#  samples avg       0.82      0.83      0.82       212

# %%
#análisis para el dataset de entrenamiento
print('Precisión : ', acc_test)
print('Report : ')
print(classif_rep_test)
# Out:
# Precisión :  0.49056603773584906
# Report :
#               precision    recall  f1-score   support
#
#            0       0.57      0.73      0.64        22
#            1       0.53      0.62      0.57        16
#            2       0.67      0.40      0.50        15
#
#    micro avg       0.57      0.60      0.59        53
#    macro avg       0.59      0.58      0.57        53
# weighted avg       0.58      0.60      0.58        53
#  samples avg       0.55      0.60      0.57        53

# %% [markdown]
# Como se puede ver, el modelo no es nada bueno, pero era lo esperable, ya que las MLPs no son el mejor modelo para análisis de imágenes.
#
# Además, al disponer de tan pocos datos, el entrenamiento de la red es bastante pobre

# %% [markdown]
# ## Save the best model

# %%
model_pkl_file = "./MLP_classifier_initialData3.pkl"

with open(model_pkl_file, 'wb') as file:
    pickle.dump(modelsTams[best_i][best_j], file)

# %% [markdown]
# ## Visualize the confusion matrix of each model

# %%
#process the real classes for the confusion matrix
y_real = list()
for i in range(0, len(tams_L)):
    instances = train_test_conditioned[i][3]
    y_instance = list()
    for k in range (0, len(instances)):
        y_instance.append(decode(instances[k]))
    y_real.append(y_instance)

# %%
for i in range(0, len(tams_L)):
    instances = train_test_conditioned[i][1] #test data
    for j in range (0, len(modelsTams[i])):
        predictions_j = list()
        for k in range (0, len(instances)):
            predictions_j.append(decode(modelsTams[i][j].predict(instances[k].reshape(1,-1))[0]))
        print("model: ", i, j)
        #confusion matrix
        cm = confusion_matrix(y_real[i], predictions_j, labels=['angry', 'happy','sad'])
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['angry', 'happy','sad'])
        disp.plot()
        plt.show()
# Out:
# model:  0 0
# model:  0 1
# model:  0 2
# model:  0 3
# model:  0 4
# model:  0 5
# model:  0 6
# model:  0 7
# model:  0 8
# model:  0 9
# model:  0 10
# model:  0 11
# model:  0 12
# model:  0 13
# model:  0 14
# model:  0 15
# model:  1 0
# model:  1 1
# model:  1 2
# model:  1 3
# model:  1 4
# model:  1 5
# model:  1 6
# model:  1 7
# model:  1 8
# model:  1 9
# model:  1 10
# model:  1 11
# model:  1 12
# model:  1 13
# model:  1 14
# model:  1 15
# model:  2 0
# model:  2 1
# model:  2 2
# model:  2 3
# model:  2 4
# model:  2 5
# model:  2 6
# model:  2 7
# model:  2 8
# model:  2 9
# model:  2 10
# model:  2 11
# model:  2 12
# model:  2 13
# model:  2 14
# model:  2 15
# model:  3 0
# model:  3 1
# model:  3 2
# model:  3 3
# model:  3 4
# model:  3 5
# model:  3 6
# model:  3 7
# model:  3 8
# model:  3 9
# model:  3 10
# model:  3 11
# model:  3 12
# model:  3 13
# model:  3 14
# model:  3 15
# model:  4 0
# model:  4 1
# model:  4 2
# model:  4 3
# model:  4 4
# model:  4 5
# model:  4 6
# model:  4 7
# model:  4 8
# model:  4 9
# model:  4 10
# model:  4 11
# model:  4 12
# model:  4 13
# model:  4 14
# model:  4 15
# model:  5 0
# model:  5 1
# model:  5 2
# model:  5 3
# model:  5 4
# model:  5 5
# model:  5 6
# model:  5 7
# model:  5 8
# model:  5 9
# model:  5 10
# model:  5 11
# model:  5 12
# model:  5 13
# model:  5 14
# model:  5 15
