# %% [markdown]
# ## 1) Importación de librerías necesarias

# %%
import pandas as pd
import os
import numpy as np
from PIL import Image
import pickle
import time
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
import tensorflow as tf
from tensorflow.keras.layers import Activation, Conv2D, Dense, Dropout
from tensorflow.keras.layers import Flatten, Input, Reshape, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## 2) Funciones que se van a usar

# %%
"""
Given the main directory of the location of the images, the URL of each image is loaded to a dataframe with his clasification
"""
def loadData(path_main_directory):
    paths_list = list()
    label_list = list()

    for subdirectory in os.listdir(path_main_directory):
        #Build the path of every subdirectory of the main_directory
        path_subdirectory = os.path.join(path_main_directory, subdirectory)

        #Iterate over all the images of the subdirectory adding the path to the dictionary
        for image_name in os.listdir(path_subdirectory):
            image_path = os.path.join(path_subdirectory, image_name)
            paths_list.append(image_path)
            label_list.append(subdirectory)

        init_data_dict = {'path' : paths_list, 'label' : label_list}

    return pd.DataFrame(init_data_dict)

# %%
"""
Given the URL of the images as a list, the information of the size of the images is returned as a dataframe
"""
def getImageSizeInfo(images_path_L):
    #list of the size of each image
    images_size_L = list()
    #List of the width of each image
    images_width_L = list()
    #List of the height of each image
    images_height_L = list()
    #List of the ratio of the size of each image
    images_ratio_L = list()

    for path in images_path_L:
        image = Image.open(path)
        #Get the size of an image (given as a tuple) and append it to the list
        images_size_L.append(image.size)
        #Get the size of the image and append it to the list
        images_width_L.append(image.size[0])
        #Get the height of the image and append it to the list
        images_height_L.append(image.size[1])
        #Get the ratio (width/height) of the image and append it to the list
        images_ratio_L.append(round(image.size[0] / image.size[1], 2))

    #Dictionary with all the information
    image_info_D = {'path' : images_path_L, 'size' : images_size_L, 'width' : images_width_L, 'height' : images_height_L,'ratio' : images_ratio_L}
    #Data frame with all the information
    return pd.DataFrame(image_info_D)

# %%
def loadImages(tams_L, images_path_L, images_class_L):
    images_BW_D = dict()

    for i in range(0, len(tams_L)):
        #List of the representation of the images in black and white as a list
        imgs_BW_L = list()
        #List of the class of each image
        class_BW_L = list()

        for j in range(0, len(images_path_L)):
            #Open image and resize it
            img = Image.open(images_path_L[j]).resize(tams_L[i])
            #Image as a list
            arr = np.asarray(img, dtype = np.int_)
            
            imgs_BW_L.append(arr)
            class_BW_L.append(images_class_L[j])

        images_BW_D[i] = (imgs_BW_L, class_BW_L)
    
    return images_BW_D

# %%
"""
Given the name of the class, returns the associated numeric class
"""
def class_to_numeric(class_list):
    l = list()
    for i in range (0, len(class_list)):
        if(class_list[i] == 'angry'):
            l.append(0)
        elif(class_list[i] == 'disgust'):
            l.append(1)
        elif(class_list[i] == 'fear'):
            l.append(2)
        elif(class_list[i] == 'happy'):
            l.append(3)
        elif(class_list[i] == 'neutral'):
            l.append(4)
        elif(class_list[i] == 'sad'):
            l.append(5)
        elif(class_list[i] == 'surprise'):
            l.append(6)
    return np.array(l)

# %%
def numeric_to_class(type):
    if (type == 0):
        return 'angry'
    elif(type == 1):
        return 'disgust'
    elif(type == 2):
        return 'fear'
    elif(type == 3):
        return 'happy'
    elif(type == 4):
        return 'neutral'
    elif(type == 5):
        return 'sad'
    else:
        return 'surprise'

# %%
def decode(class_list):
    if(class_list[0] == 1):
        return 'angry'
    elif(class_list[1] == 1):
        return 'disgust'
    elif(class_list[2] == 1):
        return 'fear'
    elif(class_list[3] == 1):
        return 'happy'
    elif(class_list[4] == 1):
        return 'neutral'
    elif(class_list[5] == 1):
        return 'sad'
    else:
        return 'surprise'

# %%
def createModel(input_shape, pool_size, kernel_size, activation_function):
    inputs = Input(shape=(input_shape), dtype=tf.float64)
    x = Conv2D(64, kernel_size, padding='same', activation=activation_function)(inputs)
    x = MaxPooling2D(pool_size=pool_size)(x)
    x = Dropout(.3)(x)
    
    x = Conv2D(32, kernel_size, padding='same', activation=activation_function)(x)
    x = MaxPooling2D(pool_size=pool_size)(x)
    x = Dropout(.3)(x)
    
    x = Flatten()(x)
    x = Dense(256, activation=activation_function)(x)
    x = Dropout(.5)(x)
    logits = Dense(7, name='logits')(x)
    outputs = Activation('softmax', name='softmax')(logits)
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(loss='categorical_crossentropy',
                              optimizer='adam',
                              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 2) Carga del conjunto de datos

# %% [markdown]
# Se van a cargar las URL de las imágenes en un dataframe junto a su clasificación.
#
# El directorio principal está divido en 3 subdirectorios titulados: angry, happy y sad. Por lo que todas las URLs (imágenes) de un directorio tendrán esa clasificación.

# %%
#Main directory of the data
path_main_directory = './fer7'

#Load the data
init_data_df = loadData(path_main_directory)

display(init_data_df.head())
display(init_data_df.tail())
# Out:
#                                     path  label
# 0  ./fer7\angry\PrivateTest_10131363.jpg  angry
# 1  ./fer7\angry\PrivateTest_10304478.jpg  angry
# 2   ./fer7\angry\PrivateTest_1054527.jpg  angry
# 3  ./fer7\angry\PrivateTest_10590091.jpg  angry
# 4   ./fer7\angry\PrivateTest_1109992.jpg  angry
#                                         path     label
# 35882  ./fer7\surprise\Training_99916297.jpg  surprise
# 35883  ./fer7\surprise\Training_99924420.jpg  surprise
# 35884  ./fer7\surprise\Training_99937001.jpg  surprise
# 35885  ./fer7\surprise\Training_99951755.jpg  surprise
# 35886  ./fer7\surprise\Training_99984132.jpg  surprise

# %% [markdown]
# Se calculan el número de ejemplos de cada clase

# %%
init_data_df['label'].value_counts()
# Out:
# label
# happy       8989
# neutral     6198
# sad         6077
# fear        5121
# angry       4953
# surprise    4002
# disgust      547
# Name: count, dtype: int64

# %% [markdown]
# Y se calcula la frecuencia de cada clase

# %%
init_data_df['label'].value_counts() / init_data_df['label'].count() * 100
# Out:
# label
# happy       25.048068
# neutral     17.270878
# sad         16.933709
# fear        14.269791
# angry       13.801655
# surprise    11.151671
# disgust      1.524229
# Name: count, dtype: float64

# %% [markdown]
# Como se puede ver, la cantidad de datos de cada clase es muy similar, lo cual es una ventaja para entrenar el modelo.

# %% [markdown]
# ## 3) Adaptación del formato de las imágenes

# %% [markdown]
# ### Elección del tamaño:
#
#   La elección del tamaño es muy importante, ya que tendrá efecto en el tiempo de entrenamiento del modelo y en la precisión del mismo. Aunque el tamaño de las imágenes del conjunto de datos elegido sea (48x48), se explorarán otros tamaños para evaluar los modelos con distintas características.

# %% [markdown]
# Se saca la información del tamaño de las imágenes y se guarda en un data frame

# %%
image_info_DF = getImageSizeInfo(init_data_df['path'].values)
display(image_info_DF.head())
# Out:
#                                     path      size  width  height  ratio
# 0  ./fer7\angry\PrivateTest_10131363.jpg  (48, 48)     48      48    1.0
# 1  ./fer7\angry\PrivateTest_10304478.jpg  (48, 48)     48      48    1.0
# 2   ./fer7\angry\PrivateTest_1054527.jpg  (48, 48)     48      48    1.0
# 3  ./fer7\angry\PrivateTest_10590091.jpg  (48, 48)     48      48    1.0
# 4   ./fer7\angry\PrivateTest_1109992.jpg  (48, 48)     48      48    1.0

# %% [markdown]
# Se van a probar con distintos tamaños (todos ellos dependiendientes de la anchura y altura original)

# %%
tams_L = list()
tams_L.append((96, 96)) #original size *2
tams_L.append((48, 48)) #original size
tams_L.append((24, 24)) #original size /2
print(tams_L)
# Out:
# [(96, 96), (48, 48), (24, 24)]

# %% [markdown]
# # Pruebas nuevas tamaños

# %% [markdown]
# Se van a generar varios conjuntos de datos: cada uno de ellos contendrá las imágenes en blanco y negro con distintos tamaños.

# %%
load_images  = loadImages(tams_L, init_data_df['path'].values, init_data_df['label'].values)

# %% [markdown]
# Se ve la forma de cada uno de los conjuntos de datos

# %%
for i in range(0, len(tams_L)):
    print(np.array(load_images[i][0]).shape)
    print(np.array(load_images[i][1]).shape)
# Out:
# (35887, 96, 96)
# (35887,)
# (35887, 48, 48)
# (35887,)
# (35887, 24, 24)
# (35887,)

# %% [markdown]
# Se visualiza una imagen de prueba para ver los cambios realizados tras redimensionar

# %%
print("Clase: ", load_images[0][1][1])
for i in range (0, len(tams_L)):
    image = load_images[i][0][1]
    plt.imshow(image)
    plt.show()
# Out:
# Clase:  angry

# %%
#Dictionary with the train test splits for all the representations
load_train_test = dict()
for i in range(0, len(tams_L)):
    X_train, X_test, y_train, y_test = train_test_split(load_images[i][0], load_images[i][1], test_size=0.2,shuffle=True)
    load_train_test[i] = (np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test))
    print('X_train shape:', np.array(X_train).shape, 'y_train shape:', np.array(y_train).shape, 'X_test shape:', np.array(X_test).shape, 'y_test shape:', np.array(y_test).shape)
# Out:
# X_train shape: (28709, 96, 96) y_train shape: (28709,) X_test shape: (7178, 96, 96) y_test shape: (7178,)
# X_train shape: (28709, 48, 48) y_train shape: (28709,) X_test shape: (7178, 48, 48) y_test shape: (7178,)
# X_train shape: (28709, 24, 24) y_train shape: (28709,) X_test shape: (7178, 24, 24) y_test shape: (7178,)

# %%
#create a model for each image size, activation function, kernel size and pooling size
activations_functions = ['relu', 'sigmoid']
kernel_sizes = [2,6]
pooling_sizes = [2,3]

modelsTams = dict()
for i in range(0, len(tams_L)):
    models = dict()
    j=0
    for pool_size in pooling_sizes:
        for kernel_size in kernel_sizes:
            for activation_function in activations_functions:
                #size of the input images
                l = list(tams_L[i]) #original size
                l[0], l[1] = l[1], l[0] #transpose
                l.append(1) #include last channel
                model = createModel(l, pool_size, kernel_size, activation_function);
                models[j] = model
                j += 1
    modelsTams[i] = models
# Out:
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#print the summary of each model
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        modelsTams[i][j].summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 96, 96, 64)        320
#
#  max_pooling2d (MaxPooling2  (None, 48, 48, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 48, 48, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        8224
#
#  max_pooling2d_1 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 256)               4718848
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 4729191 (18.04 MB)
# Trainable params: 4729191 (18.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 64)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        8224
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten_1 (Flatten)         (None, 18432)             0
#
#  dense_1 (Dense)             (None, 256)               4718848
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 4729191 (18.04 MB)
# Trainable params: 4729191 (18.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 96, 96, 64)        2368
#
#  max_pooling2d_4 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 32)        73760
#
#  max_pooling2d_5 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 24, 24, 32)        0
#
#  flatten_2 (Flatten)         (None, 18432)             0
#
#  dense_2 (Dense)             (None, 256)               4718848
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 4796775 (18.30 MB)
# Trainable params: 4796775 (18.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_6 (Conv2D)           (None, 96, 96, 64)        2368
#
#  max_pooling2d_6 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 32)        73760
#
#  max_pooling2d_7 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 24, 24, 32)        0
#
#  flatten_3 (Flatten)         (None, 18432)             0
#
#  dense_3 (Dense)             (None, 256)               4718848
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 4796775 (18.30 MB)
# Trainable params: 4796775 (18.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 96, 96, 64)        320
#
#  max_pooling2d_8 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        8224
#
#  max_pooling2d_9 (MaxPoolin  (None, 10, 10, 32)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_4 (Flatten)         (None, 3200)              0
#
#  dense_4 (Dense)             (None, 256)               819456
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 829799 (3.17 MB)
# Trainable params: 829799 (3.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 96, 96, 64)        320
#
#  max_pooling2d_10 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_15 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        8224
#
#  max_pooling2d_11 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_5 (Flatten)         (None, 3200)              0
#
#  dense_5 (Dense)             (None, 256)               819456
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 829799 (3.17 MB)
# Trainable params: 829799 (3.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_12 (Conv2D)          (None, 96, 96, 64)        2368
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 32)        73760
#
#  max_pooling2d_13 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_19 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_6 (Flatten)         (None, 3200)              0
#
#  dense_6 (Dense)             (None, 256)               819456
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 897383 (3.42 MB)
# Trainable params: 897383 (3.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_14 (Conv2D)          (None, 96, 96, 64)        2368
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 64)        0
#  ng2D)
#
#  dropout_21 (Dropout)        (None, 32, 32, 64)        0
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 32)        73760
#
#  max_pooling2d_15 (MaxPooli  (None, 10, 10, 32)        0
#  ng2D)
#
#  dropout_22 (Dropout)        (None, 10, 10, 32)        0
#
#  flatten_7 (Flatten)         (None, 3200)              0
#
#  dense_7 (Dense)             (None, 256)               819456
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 897383 (3.42 MB)
# Trainable params: 897383 (3.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_16 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_16 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_24 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 32)        8224
#
#  max_pooling2d_17 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_25 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_8 (Flatten)         (None, 4608)              0
#
#  dense_8 (Dense)             (None, 256)               1179904
#
#  dropout_26 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 1190247 (4.54 MB)
# Trainable params: 1190247 (4.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_18 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_27 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 32)        8224
#
#  max_pooling2d_19 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_28 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_9 (Flatten)         (None, 4608)              0
#
#  dense_9 (Dense)             (None, 256)               1179904
#
#  dropout_29 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 1190247 (4.54 MB)
# Trainable params: 1190247 (4.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_20 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_20 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_30 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 32)        73760
#
#  max_pooling2d_21 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_31 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_10 (Flatten)        (None, 4608)              0
#
#  dense_10 (Dense)            (None, 256)               1179904
#
#  dropout_32 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 1257831 (4.80 MB)
# Trainable params: 1257831 (4.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_22 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_22 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_33 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_23 (Conv2D)          (None, 24, 24, 32)        73760
#
#  max_pooling2d_23 (MaxPooli  (None, 12, 12, 32)        0
#  ng2D)
#
#  dropout_34 (Dropout)        (None, 12, 12, 32)        0
#
#  flatten_11 (Flatten)        (None, 4608)              0
#
#  dense_11 (Dense)            (None, 256)               1179904
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 1257831 (4.80 MB)
# Trainable params: 1257831 (4.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_24 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_24 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_36 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 32)        8224
#
#  max_pooling2d_25 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_37 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_12 (Flatten)        (None, 800)               0
#
#  dense_12 (Dense)            (None, 256)               205056
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 215399 (841.40 KB)
# Trainable params: 215399 (841.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_26 (Conv2D)          (None, 48, 48, 64)        320
#
#  max_pooling2d_26 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_39 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_27 (Conv2D)          (None, 16, 16, 32)        8224
#
#  max_pooling2d_27 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_40 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_13 (Flatten)        (None, 800)               0
#
#  dense_13 (Dense)            (None, 256)               205056
#
#  dropout_41 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 215399 (841.40 KB)
# Trainable params: 215399 (841.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_28 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_28 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_42 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 32)        73760
#
#  max_pooling2d_29 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_43 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_14 (Flatten)        (None, 800)               0
#
#  dense_14 (Dense)            (None, 256)               205056
#
#  dropout_44 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 282983 (1.08 MB)
# Trainable params: 282983 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_16 (InputLayer)       [(None, 48, 48, 1)]       0
#
#  conv2d_30 (Conv2D)          (None, 48, 48, 64)        2368
#
#  max_pooling2d_30 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  dropout_45 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 32)        73760
#
#  max_pooling2d_31 (MaxPooli  (None, 5, 5, 32)          0
#  ng2D)
#
#  dropout_46 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_15 (Flatten)        (None, 800)               0
#
#  dense_15 (Dense)            (None, 256)               205056
#
#  dropout_47 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 282983 (1.08 MB)
# Trainable params: 282983 (1.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_32 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_32 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_48 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_33 (Conv2D)          (None, 12, 12, 32)        8224
#
#  max_pooling2d_33 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_49 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_16 (Flatten)        (None, 1152)              0
#
#  dense_16 (Dense)            (None, 256)               295168
#
#  dropout_50 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 305511 (1.17 MB)
# Trainable params: 305511 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_18 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_34 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_34 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_51 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_35 (Conv2D)          (None, 12, 12, 32)        8224
#
#  max_pooling2d_35 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_52 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_17 (Flatten)        (None, 1152)              0
#
#  dense_17 (Dense)            (None, 256)               295168
#
#  dropout_53 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 305511 (1.17 MB)
# Trainable params: 305511 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_19 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_36 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_36 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_54 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_37 (Conv2D)          (None, 12, 12, 32)        73760
#
#  max_pooling2d_37 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_55 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_18 (Flatten)        (None, 1152)              0
#
#  dense_18 (Dense)            (None, 256)               295168
#
#  dropout_56 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 373095 (1.42 MB)
# Trainable params: 373095 (1.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_38 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_38 (MaxPooli  (None, 12, 12, 64)        0
#  ng2D)
#
#  dropout_57 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 12, 12, 32)        73760
#
#  max_pooling2d_39 (MaxPooli  (None, 6, 6, 32)          0
#  ng2D)
#
#  dropout_58 (Dropout)        (None, 6, 6, 32)          0
#
#  flatten_19 (Flatten)        (None, 1152)              0
#
#  dense_19 (Dense)            (None, 256)               295168
#
#  dropout_59 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 373095 (1.42 MB)
# Trainable params: 373095 (1.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_21 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_40 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_60 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_41 (Conv2D)          (None, 8, 8, 32)          8224
#
#  max_pooling2d_41 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_61 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_20 (Flatten)        (None, 128)               0
#
#  dense_20 (Dense)            (None, 256)               33024
#
#  dropout_62 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 43367 (169.40 KB)
# Trainable params: 43367 (169.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_42 (Conv2D)          (None, 24, 24, 64)        320
#
#  max_pooling2d_42 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_63 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 32)          8224
#
#  max_pooling2d_43 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_64 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_21 (Flatten)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 256)               33024
#
#  dropout_65 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 43367 (169.40 KB)
# Trainable params: 43367 (169.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_23 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_44 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_44 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_66 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_45 (Conv2D)          (None, 8, 8, 32)          73760
#
#  max_pooling2d_45 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_67 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_22 (Flatten)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 256)               33024
#
#  dropout_68 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 110951 (433.40 KB)
# Trainable params: 110951 (433.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "model_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 24, 24, 1)]       0
#
#  conv2d_46 (Conv2D)          (None, 24, 24, 64)        2368
#
#  max_pooling2d_46 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  dropout_69 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_47 (Conv2D)          (None, 8, 8, 32)          73760
#
#  max_pooling2d_47 (MaxPooli  (None, 2, 2, 32)          0
#  ng2D)
#
#  dropout_70 (Dropout)        (None, 2, 2, 32)          0
#
#  flatten_23 (Flatten)        (None, 128)               0
#
#  dense_23 (Dense)            (None, 256)               33024
#
#  dropout_71 (Dropout)        (None, 256)               0
#
#  logits (Dense)              (None, 7)                 1799
#
#  softmax (Activation)        (None, 7)                 0
#
# =================================================================
# Total params: 110951 (433.40 KB)
# Trainable params: 110951 (433.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#data conditioning for each model
train_test_conditioned = dict()

for i in range(0, len(tams_L)):
    X_train = load_train_test[i][0]
    X_train = X_train.astype('float32') / 255
    
    X_test = load_train_test[i][1]
    X_test = X_test.astype('float32') / 255
    
    y_train = load_train_test[i][2]
    y_train = class_to_numeric(y_train) # Converts the string class to numeric class
    y_train = to_categorical(y_train) # Converts the classes into one-hot-vector
    
    y_test = load_train_test[i][3]
    y_test = class_to_numeric(y_test) # Converts the string class to numeric class
    y_test = to_categorical(y_test) # Converts the classes into one-hot-vector

    print('X_train shape:', X_train.shape, 'X_test shape:', X_test.shape, 'y_train shape:', y_train.shape, 'y_test shape:', y_test.shape)
    
    train_test_conditioned[i] = (X_train, X_test, y_train, y_test)
# Out:
# X_train shape: (28709, 96, 96) X_test shape: (7178, 96, 96) y_train shape: (28709, 7) y_test shape: (7178, 7)
# X_train shape: (28709, 48, 48) X_test shape: (7178, 48, 48) y_train shape: (28709, 7) y_test shape: (7178, 7)
# X_train shape: (28709, 24, 24) X_test shape: (7178, 24, 24) y_train shape: (28709, 7) y_test shape: (7178, 7)

# %% [markdown]
# ## Train the models

# %%
#train the models
times = list()
accuracies = list()
for i in range(0, len(tams_L)):
    time_tam = list()
    accuracy_tam = list()
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        start = time.time()
        history = modelsTams[i][j].fit(train_test_conditioned[i][0],
              train_test_conditioned[i][2],
              epochs=40,
              batch_size=128,
              verbose=1,
              validation_data=(train_test_conditioned[i][1], train_test_conditioned[i][3])
              )
        stop = time.time()
        time_tam.append(stop-start)
        accuracy_tam.append(history.history['accuracy'][39])
    times.append(time_tam)
    accuracies.append(accuracy_tam)
# Out:
# Model  0 0
# Epoch 1/40
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\javie\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 225/225 [==============================] - 51s 222ms/step - loss: 1.8714 - accuracy: 0.2450 - val_loss: 1.7777 - val_accuracy: 0.2792
# Epoch 2/40
# 225/225 [==============================] - 56s 248ms/step - loss: 1.7286 - accuracy: 0.3016 - val_loss: 1.6771 - val_accuracy: 0.3568
# Epoch 3/40
# 225/225 [==============================] - 53s 235ms/step - loss: 1.6814 - accuracy: 0.3331 - val_loss: 1.6503 - val_accuracy: 0.3633
# Epoch 4/40
# 225/225 [==============================] - 52s 232ms/step - loss: 1.6561 - accuracy: 0.3440 - val_loss: 1.6128 - val_accuracy: 0.3752
# Epoch 5/40
# 225/225 [==============================] - 55s 246ms/step - loss: 1.6406 - accuracy: 0.3524 - val_loss: 1.6069 - val_accuracy: 0.3778
# Epoch 6/40
# 225/225 [==============================] - 56s 248ms/step - loss: 1.6206 - accuracy: 0.3627 - val_loss: 1.5701 - val_accuracy: 0.3884
# Epoch 7/40
# 225/225 [==============================] - 56s 247ms/step - loss: 1.5900 - accuracy: 0.3725 - val_loss: 1.5493 - val_accuracy: 0.4032
# Epoch 8/40
# 225/225 [==============================] - 54s 241ms/step - loss: 1.5589 - accuracy: 0.3895 - val_loss: 1.5151 - val_accuracy: 0.4103
# Epoch 9/40
# 225/225 [==============================] - 53s 237ms/step - loss: 1.5359 - accuracy: 0.4004 - val_loss: 1.5086 - val_accuracy: 0.4235
# Epoch 10/40
# 225/225 [==============================] - 54s 239ms/step - loss: 1.5146 - accuracy: 0.4094 - val_loss: 1.4991 - val_accuracy: 0.4224
# Epoch 11/40
# 225/225 [==============================] - 53s 237ms/step - loss: 1.4922 - accuracy: 0.4156 - val_loss: 1.4609 - val_accuracy: 0.4313
# Epoch 12/40
# 225/225 [==============================] - 53s 235ms/step - loss: 1.4751 - accuracy: 0.4215 - val_loss: 1.4590 - val_accuracy: 0.4373
# Epoch 13/40
# 225/225 [==============================] - 53s 238ms/step - loss: 1.4603 - accuracy: 0.4323 - val_loss: 1.4377 - val_accuracy: 0.4429
# Epoch 14/40
# 225/225 [==============================] - 49s 219ms/step - loss: 1
40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.2857 - accuracy: 0.5061 - val_loss: 1.2897 - val_accuracy: 0.5007
# Epoch 19/40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.2740 - accuracy: 0.5121 - val_loss: 1.2797 - val_accuracy: 0.5049
# Epoch 20/40
# 225/225 [==============================] - 33s 145ms/step - loss: 1.2577 - accuracy: 0.5176 - val_loss: 1.2770 - val_accuracy: 0.5138
# Epoch 21/40
# 225/225 [==============================] - 33s 146ms/step - loss: 1.2468 - accuracy: 0.5221 - val_loss: 1.2769 - val_accuracy: 0.5061
# Epoch 22/40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.2419 - accuracy: 0.5239 - val_loss: 1.2631 - val_accuracy: 0.5163
# Epoch 23/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.2311 - accuracy: 0.5272 - val_loss: 1.2708 - val_accuracy: 0.5123
# Epoch 24/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.2233 - accuracy: 0.5321 - val_loss: 1.2657 - val_accuracy: 0.5100
# Epoch 25/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.2092 - accuracy: 0.5342 - val_loss: 1.2488 - val_accuracy: 0.5223
# Epoch 26/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.2000 - accuracy: 0.5412 - val_loss: 1.2502 - val_accuracy: 0.5238
# Epoch 27/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.1901 - accuracy: 0.5474 - val_loss: 1.2445 - val_accuracy: 0.5224
# Epoch 28/40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.1829 - accuracy: 0.5470 - val_loss: 1.2410 - val_accuracy: 0.5247
# Epoch 29/40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.1720 - accuracy: 0.5536 - val_loss: 1.2473 - val_accuracy: 0.5220
# Epoch 30/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.1674 - accuracy: 0.5537 - val_loss: 1.2311 - val_accuracy: 0.5313
# Epoch 31/40
# 225/225 [==============================] - 32s 141ms/step - loss: 1.1524 - accuracy: 0.5586 - val_loss: 1.2285 - val_accuracy: 0.5315
# Epoch 32/40
# 225/225 [==============================] - 32s 140ms/step - loss: 1.1397 - accuracy: 0.5630 - val_loss: 1.2247 - val_accuracy: 0.5316
# Epoch 33/40
# 225/225 [==============================] - 32s 142ms/step - loss: 1.1405 - accuracy: 0.5659 - val_loss: 1.2315 - val_accuracy: 0.5284
# Epoch 34/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.1251 - accuracy: 0.5694 - val_loss: 1.2421 - val_accuracy: 0.5287
# Epoch 35/40
# 225/225 [==============================] - 32s 144ms/step - loss: 1.1176 - accuracy: 0.5752 - val_loss: 1.2245 - val_accuracy: 0.5323
# Epoch 36/40
# 225/225 [==============================] - 32s 143ms/step - loss: 1.1072 - accuracy: 0.5785 - val_loss: 1.2301 - val_accuracy: 0.5364
# Epoch 37/40
# 225/225 [==============================] - 31s 140ms/step - loss: 1.0990 - accuracy: 0.5804 - val_loss: 1.2250 - val_accuracy: 0.5389
# Epoch 38/40
# 225/225 [==============================] - 31s 140ms/step - loss: 1.0962 - accuracy: 0.5821 - val_loss: 1.2392 - val_accuracy: 0.5330
# Epoch 39/40
# 225/225 [==============================] - 31s 140ms/step - loss: 1.0858 - accuracy: 0.5838 - val_loss: 1.2188 - val_accuracy: 0.5401
# Epoch 40/40
# 225/225 [==============================] - 31s 139ms/step - loss: 1.0780 - accuracy: 0.5888 - val_loss: 1.2183 - val_accuracy: 0.5422
# Model  0 5
# Epoch 1/40
# 225/225 [==============================] - 38s 161ms/step - loss: 1.8877 - accuracy: 0.2254 - val_loss: 1.8214 - val_accuracy: 0.2445
40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.8133 - accuracy: 0.2501 - val_loss: 1.8086 - val_accuracy: 0.2519
# Epoch 13/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.8128 - accuracy: 0.2501 - val_loss: 1.8048 - val_accuracy: 0.2519
# Epoch 14/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.8064 - accuracy: 0.2496 - val_loss: 1.7995 - val_accuracy: 0.2512
# Epoch 15/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7980 - accuracy: 0.2504 - val_loss: 1.7888 - val_accuracy: 0.2516
# Epoch 16/40
# 225/225 [==============================] - 3s 14ms/step - loss: 1.7945 - accuracy: 0.2509 - val_loss: 1.7892 - val_accuracy: 0.2509
# Epoch 17/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7945 - accuracy: 0.2494 - val_loss: 1.7828 - val_accuracy: 0.2555
# Epoch 18/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7905 - accuracy: 0.2520 - val_loss: 1.7793 - val_accuracy: 0.2568
# Epoch 19/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7920 - accuracy: 0.2508 - val_loss: 1.7785 - val_accuracy: 0.2542
# Epoch 20/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7897 - accuracy: 0.2546 - val_loss: 1.7790 - val_accuracy: 0.2548
# Epoch 21/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7877 - accuracy: 0.2556 - val_loss: 1.7790 - val_accuracy: 0.2572
# Epoch 22/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7878 - accuracy: 0.2527 - val_loss: 1.7758 - val_accuracy: 0.2579
# Epoch 23/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7877 - accuracy: 0.2545 - val_loss: 1.7751 - val_accuracy: 0.2611
# Epoch 24/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7868 - accuracy: 0.2540 - val_loss: 1.7770 - val_accuracy: 0.2614
# Epoch 25/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7869 - accuracy: 0.2553 - val_loss: 1.7784 - val_accuracy: 0.2654
# Epoch 26/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7849 - accuracy: 0.2547 - val_loss: 1.7815 - val_accuracy: 0.2605
# Epoch 27/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7833 - accuracy: 0.2572 - val_loss: 1.7720 - val_accuracy: 0.2669
# Epoch 28/40
# 225/225 [==============================] - 3s 16ms/step - loss: 1.7821 - accuracy: 0.2556 - val_loss: 1.7713 - val_accuracy: 0.2712
# Epoch 29/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7805 - accuracy: 0.2615 - val_loss: 1.7648 - val_accuracy: 0.2668
# Epoch 30/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7782 - accuracy: 0.2592 - val_loss: 1.7631 - val_accuracy: 0.2721
# Epoch 31/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7744 - accuracy: 0.2642 - val_loss: 1.7505 - val_accuracy: 0.2781
# Epoch 32/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7676 - accuracy: 0.2701 - val_loss: 1.7452 - val_accuracy: 0.2778
# Epoch 33/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7632 - accuracy: 0.2735 - val_loss: 1.7366 - val_accuracy: 0.2850
# Epoch 34/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7579 - accuracy: 0.2782 - val_loss: 1.7262 - val_accuracy: 0.2966
# Epoch 35/40
# 225/225 [==============================] - 4s 16ms/step - loss: 1.7521 - accuracy: 0.2834 - val_loss: 1.7225 - val_accuracy: 0.2910
# Epoch 36/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7492 - accuracy: 0.2831 - val_loss: 1.7267 - val_accuracy: 0.2873
# Epoch 37/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7446 - accuracy: 0.2842 - val_loss: 1.7082 - val_accuracy: 0.3016
# Epoch 38/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7438 - accuracy: 0.2824 - val_loss: 1.7111 - val_accuracy: 0.2941
# Epoch 39/40
# 225/225 [==============================] - 3s 15ms/step - loss: 1.7380 - accuracy: 0.2883 - val_loss: 1.7110 - val_accuracy: 0.2960
# Epoch 40/40
# 225/225 [==============================] - 3s 14ms/step - loss: 1.7367 - accuracy: 0.2900 - val_loss: 1.7096 - val_accuracy: 0.3015
# Model  2 6
# Epoch 1/40
# 225/225 [==============================] - 5s 19ms/step - loss: 1.8202 - accuracy: 0.2465 - val_loss: 1.7540 - val_accuracy: 0.2803
# Epoch 2/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.7165 - accuracy: 0.3129 - val_loss: 1.6172 - val_accuracy: 0.3753
# Epoch 3/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.6454 - accuracy: 0.3558 - val_loss: 1.5624 - val_accuracy: 0.4035
# Epoch 4/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.6037 - accuracy: 0.3762 - val_loss: 1.5148 - val_accuracy: 0.4164
# Epoch 5/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.5762 - accuracy: 0.3867 - val_loss: 1.5075 - val_accuracy: 0.4260
# Epoch 6/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.5531 - accuracy: 0.3950 - val_loss: 1.4955 - val_accuracy: 0.4252
# Epoch 7/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.5382 - accuracy: 0.4023 - val_loss: 1.4639 - val_accuracy: 0.4437
# Epoch 8/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.5277 - accuracy: 0.4086 - val_loss: 1.4457 - val_accuracy: 0.4472
# Epoch 9/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.5125 - accuracy: 0.4113 - val_loss: 1.4326 - val_accuracy: 0.4551
# Epoch 10/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4975 - accuracy: 0.4182 - val_loss: 1.4207 - val_accuracy: 0.4515
# Epoch 11/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.4875 - accuracy: 0.4235 - val_loss: 1.4209 - val_accuracy: 0.4565
# Epoch 12/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4762 - accuracy: 0.4250 - val_loss: 1.4120 - val_accuracy: 0.4607
# Epoch 13/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4632 - accuracy: 0.4368 - val_loss: 1.3908 - val_accuracy: 0.4703
# Epoch 14/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4605 - accuracy: 0.4400 - val_loss: 1.4018 - val_accuracy: 0.4634
# Epoch 15/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4523 - accuracy: 0.4385 - val_loss: 1.3836 - val_accuracy: 0.4748
# Epoch 16/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4418 - accuracy: 0.4492 - val_loss: 1.3780 - val_accuracy: 0.4739
# Epoch 17/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4321 - accuracy: 0.4502 - val_loss: 1.3665 - val_accuracy: 0.4778
# Epoch 18/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4296 - accuracy: 0.4513 - val_loss: 1.3754 - val_accuracy: 0.4716
# Epoch 19/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.4223 - accuracy: 0.4554 - val_loss: 1.3693 - val_accuracy: 0.4773
# Epoch 20/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.4161 - accuracy: 0.4540 - val_loss: 1.3765 - val_accuracy: 0.4734
# Epoch 21/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4151 - accuracy: 0.4549 - val_loss: 1.3631 - val_accuracy: 0.4772
# Epoch 22/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4025 - accuracy: 0.4586 - val_loss: 1.3513 - val_accuracy: 0.4783
# Epoch 23/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.4009 - accuracy: 0.4614 - val_loss: 1.3468 - val_accuracy: 0.4858
# Epoch 24/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3985 - accuracy: 0.4633 - val_loss: 1.3506 - val_accuracy: 0.4845
# Epoch 25/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3848 - accuracy: 0.4695 - val_loss: 1.3474 - val_accuracy: 0.4826
# Epoch 26/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.3818 - accuracy: 0.4710 - val_loss: 1.3455 - val_accuracy: 0.4880
# Epoch 27/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3742 - accuracy: 0.4706 - val_loss: 1.3388 - val_accuracy: 0.4847
# Epoch 28/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3744 - accuracy: 0.4732 - val_loss: 1.3304 - val_accuracy: 0.4915
# Epoch 29/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3738 - accuracy: 0.4736 - val_loss: 1.3419 - val_accuracy: 0.4872
# Epoch 30/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3707 - accuracy: 0.4742 - val_loss: 1.3396 - val_accuracy: 0.4866
# Epoch 31/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3649 - accuracy: 0.4764 - val_loss: 1.3211 - val_accuracy: 0.4954
# Epoch 32/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.3625 - accuracy: 0.4759 - val_loss: 1.3246 - val_accuracy: 0.4875
# Epoch 33/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3542 - accuracy: 0.4813 - val_loss: 1.3191 - val_accuracy: 0.4957
# Epoch 34/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3544 - accuracy: 0.4811 - val_loss: 1.3292 - val_accuracy: 0.4957
# Epoch 35/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3565 - accuracy: 0.4810 - val_loss: 1.3182 - val_accuracy: 0.4965
# Epoch 36/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3512 - accuracy: 0.4830 - val_loss: 1.3136 - val_accuracy: 0.4989
# Epoch 37/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3384 - accuracy: 0.4883 - val_loss: 1.3164 - val_accuracy: 0.4989
# Epoch 38/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.3433 - accuracy: 0.4871 - val_loss: 1.3190 - val_accuracy: 0.4974
# Epoch 39/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3422 - accuracy: 0.4843 - val_loss: 1.3067 - val_accuracy: 0.4983
# Epoch 40/40
# 225/225 [==============================] - 4s 18ms/step - loss: 1.3272 - accuracy: 0.4931 - val_loss: 1.3188 - val_accuracy: 0.4967
# Model  2 7
# Epoch 1/40
# 225/225 [==============================] - 5s 20ms/step - loss: 1.8773 - accuracy: 0.2189 - val_loss: 1.8108 - val_accuracy: 0.2519
# Epoch 2/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.8206 - accuracy: 0.2480 - val_loss: 1.8107 - val_accuracy: 0.2519
# Epoch 3/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.8181 - accuracy: 0.2490 - val_loss: 1.8090 - val_accuracy: 0.2519
# Epoch 4/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.8160 - accuracy: 0.2501 - val_loss: 1.8100 - val_accuracy: 0.2519
# Epoch 5/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.8145 - accuracy: 0.2501 - val_loss: 1.8050 - val_accuracy: 0.2519
# Epoch 6/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.8045 - accuracy: 0.2495 - val_loss: 1.7903 - val_accuracy: 0.2519
# Epoch 7/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7960 - accuracy: 0.2497 - val_loss: 1.7818 - val_accuracy: 0.2519
# Epoch 8/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.7919 - accuracy: 0.2481 - val_loss: 1.7791 - val_accuracy: 0.2519
# Epoch 9/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.7899 - accuracy: 0.2492 - val_loss: 1.7747 - val_accuracy: 0.2561
# Epoch 10/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7812 - accuracy: 0.2566 - val_loss: 1.7613 - val_accuracy: 0.2655
# Epoch 11/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7716 - accuracy: 0.2633 - val_loss: 1.7506 - val_accuracy: 0.2768
# Epoch 12/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7537 - accuracy: 0.2770 - val_loss: 1.7189 - val_accuracy: 0.3051
# Epoch 13/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7349 - accuracy: 0.2938 - val_loss: 1.7021 - val_accuracy: 0.3240
# Epoch 14/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.7219 - accuracy: 0.3028 - val_loss: 1.6835 - val_accuracy: 0.3360
# Epoch 15/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.7115 - accuracy: 0.3110 - val_loss: 1.6651 - val_accuracy: 0.3328
# Epoch 16/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.6978 - accuracy: 0.3210 - val_loss: 1.6599 - val_accuracy: 0.3422
# Epoch 17/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6889 - accuracy: 0.3238 - val_loss: 1.6445 - val_accuracy: 0.3440
# Epoch 18/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6791 - accuracy: 0.3299 - val_loss: 1.6327 - val_accuracy: 0.3543
# Epoch 19/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.6733 - accuracy: 0.3328 - val_loss: 1.6358 - val_accuracy: 0.3508
# Epoch 20/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6671 - accuracy: 0.3391 - val_loss: 1.6241 - val_accuracy: 0.3534
# Epoch 21/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6612 - accuracy: 0.3392 - val_loss: 1.6210 - val_accuracy: 0.3670
# Epoch 22/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6530 - accuracy: 0.3431 - val_loss: 1.6005 - val_accuracy: 0.3658
# Epoch 23/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6493 - accuracy: 0.3454 - val_loss: 1.6071 - val_accuracy: 0.3735
# Epoch 24/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6427 - accuracy: 0.3498 - val_loss: 1.5883 - val_accuracy: 0.3767
# Epoch 25/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6360 - accuracy: 0.3537 - val_loss: 1.5825 - val_accuracy: 0.3814
# Epoch 26/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6321 - accuracy: 0.3538 - val_loss: 1.5905 - val_accuracy: 0.3756
# Epoch 27/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.6233 - accuracy: 0.3585 - val_loss: 1.5697 - val_accuracy: 0.3827
# Epoch 28/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6188 - accuracy: 0.3628 - val_loss: 1.5720 - val_accuracy: 0.3816
# Epoch 29/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6183 - accuracy: 0.3612 - val_loss: 1.5657 - val_accuracy: 0.3948
# Epoch 30/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.6130 - accuracy: 0.3663 - val_loss: 1.5528 - val_accuracy: 0.3897
# Epoch 31/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6079 - accuracy: 0.3692 - val_loss: 1.5511 - val_accuracy: 0.3880
# Epoch 32/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6024 - accuracy: 0.3708 - val_loss: 1.5478 - val_accuracy: 0.4026
# Epoch 33/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.6046 - accuracy: 0.3692 - val_loss: 1.5478 - val_accuracy: 0.3931
# Epoch 34/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.5919 - accuracy: 0.3748 - val_loss: 1.5556 - val_accuracy: 0.3915
# Epoch 35/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.5932 - accuracy: 0.3720 - val_loss: 1.5413 - val_accuracy: 0.3930
# Epoch 36/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.5921 - accuracy: 0.3749 - val_loss: 1.5400 - val_accuracy: 0.4030
# Epoch 37/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.5857 - accuracy: 0.3763 - val_loss: 1.5350 - val_accuracy: 0.4018
# Epoch 38/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.5820 - accuracy: 0.3823 - val_loss: 1.5226 - val_accuracy: 0.4065
# Epoch 39/40
# 225/225 [==============================] - 4s 20ms/step - loss: 1.5775 - accuracy: 0.3821 - val_loss: 1.5235 - val_accuracy: 0.4033
# Epoch 40/40
# 225/225 [==============================] - 4s 19ms/step - loss: 1.5768 - accuracy: 0.3833 - val_loss: 1.5220 - val_accuracy: 0.4099

# %%
## print the accuracies and times obtained
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (8,8))

ax1.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in accuracies for x in sublist], color='blue', marker='.')
ax1.set_title('Accuracies')
ax1.set_xlabel('Model')
ax1.set_ylabel('Accuracy')

ax2.scatter(list(range(0, len(tams_L)*len(modelsTams[0]))), [x for sublist in times for x in sublist], color='orange', marker='.')
ax2.set_title('Times')
ax2.set_xlabel('Model')
ax2.set_ylabel('Time(s)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluate the models

# %%
acc = 0
for i in range(0, len(tams_L)):
    for j in range (0, len(modelsTams[i])):
        print("Model ", i, j);
        score = modelsTams[i][j].evaluate(train_test_conditioned[i][1], train_test_conditioned[i][3], verbose=0)
        print("Test accuracy: ", score[1])
        if(score[1] > acc):
            acc = score[1]
            best_i = i
            best_j = j
print("Best model ", best_i, best_j)
# Out:
# Model  0 0
# Test accuracy:  0.48202842473983765
# Model  0 1
# Test accuracy:  0.24449707567691803
# Model  0 2
# Test accuracy:  0.5167177319526672
# Model  0 3
# Test accuracy:  0.24449707567691803
# Model  0 4
# Test accuracy:  0.5422123074531555
# Model  0 5
# Test accuracy:  0.4335469603538513
# Model  0 6
# Test accuracy:  0.5579548478126526
# Model  0 7
# Test accuracy:  0.5139314532279968
# Model  1 0
# Test accuracy:  0.5391473770141602
# Model  1 1
# Test accuracy:  0.43898022174835205
# Model  1 2
# Test accuracy:  0.5619949698448181
# Model  1 3
# Test accuracy:  0.5133742094039917
# Model  1 4
# Test accuracy:  0.5440233945846558
# Model  1 5
# Test accuracy:  0.40665924549102783
# Model  1 6
# Test accuracy:  0.5696572661399841
# Model  1 7
# Test accuracy:  0.49191975593566895
# Model  2 0
# Test accuracy:  0.522568941116333
# Model  2 1
# Test accuracy:  0.4067985415458679
# Model  2 2
# Test accuracy:  0.530927836894989
# Model  2 3
# Test accuracy:  0.47575926780700684
# Model  2 4
# Test accuracy:  0.44803565740585327
# Model  2 5
# Test accuracy:  0.30147674679756165
# Model  2 6
# Test accuracy:  0.4966564476490021
# Model  2 7
# Test accuracy:  0.4098634719848633
# Best model  1 6

# %%
# Visualize the summary of the best model
activation_function = modelsTams[best_i][best_j].layers[1].activation
kernel_size = modelsTams[best_i][best_j].layers[1].kernel_size
pool_size = modelsTams[best_i][best_j].layers[2].pool_size

print("Input size:", tams_L[best_i])
print("Activation function: ", activation_function)
print("Kernel size: ", kernel_size)
print("Pool size: ", pool_size)
# Out:
# Input size: (48, 48)
# Activation function:  <function relu at 0x000001F087C76AC0>
# Kernel size:  (6, 6)
# Pool size:  (3, 3)

# %% [markdown]
# ## Save the best model

# %%
model_pkl_file = "./CNN_classifier_fer7.pkl"

with open(model_pkl_file, 'wb') as file:
    pickle.dump(modelsTams[best_i][best_j], file)

# %% [markdown]
# ## Visualize the confusion matrix of the best model

# %%
#load the cnn model from the pickle file
model_pkl_file = "./CNN_classifier_fer7.pkl"

with open(model_pkl_file, 'rb') as file:
    model = pickle.load(file)

# %%
#process the real classes for the confusion matrix
y_real = list()
for i in range(0, len(tams_L)):
    instances = train_test_conditioned[i][3]
    y_instance = list()
    for k in range (0, len(instances)):
        y_instance.append(decode(instances[k]))
    y_real.append(y_instance)

# %%
#size of the data used
l = list(tams_L[1]) #original size
l[0], l[1] = l[1], l[0] #transpose
l.append(1)
l = (1,) + tuple(l)
instances = train_test_conditioned[1][1] #test data
predictions_j = list()
for k in range (0, len(instances)):
    predictions_j.append(numeric_to_class(model(instances[k].reshape(l)).numpy().argmax(axis=1)[0]))
#confusion matrix
cm = confusion_matrix(y_real[1], predictions_j, labels=['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'])
disp.plot()
plt.show()
